# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/RNAseqHarm/MSBB_Differential_Expression_(diagnosis-sex-age-death).tsv', delimiter="\t")

# %%
df.columns
# Out:
# Index(['Comparison', 'ensembl_gene_id', 'logFC', 'CI.L', 'CI.R', 'AveExpr',
#        't', 'P.Value', 'adj.P.Val', 'Direction', 'hgnc_symbol',
#        'percentage_gene_gc_content', 'gene_biotype', 'chromosome_name',
#        'gene_length'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181888 entries, 0 to 181887
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Comparison                  181888 non-null  object
#  1   ensembl_gene_id             181888 non-null  object
#  2   logFC                       181888 non-null  float64
#  3   CI.L                        181888 non-null  float64
#  4   CI.R                        181888 non-null  float64
#  5   AveExpr                     181888 non-null  float64
#  6   t                           181888 non-null  float64
#  7   P.Value                     181888 non-null  float64
#  8   adj.P.Val                   181888 non-null  float64
#  9   Direction                   181888 non-null  object
#  10  hgnc_symbol                 181888 non-null  object
#  11  percentage_gene_gc_content  181888 non-null  float64
#  12  gene_biotype                181888 non-null  object
#  13  chromosome_name             181888 non-null  object
#  14  gene_length                 181888 non-null  int64
# dtypes: float64(8), int64(1), object(6)
# memory usage: 20.8+ MB

# %%
df.head()
# Out:
#                                           Comparison  ensembl_gene_id  \
# 0  diagnosis_sex_tissue*age_death.AD_female_FP - ...  ENSG00000114374
# 1  diagnosis_sex_tissue*age_death.AD_female_FP - ...  ENSG00000129824
# 2  diagnosis_sex_tissue*age_death.AD_female_FP - ...  ENSG00000067048
# 3  diagnosis_sex_tissue*age_death.AD_female_FP - ...  ENSG00000183878
# 4  diagnosis_sex_tissue*age_death.AD_female_FP - ...  ENSG00000263934
#
#       logFC      CI.L      CI.R   AveExpr         t       P.Value  \
# 0 -0.371193 -0.494065 -0.248321  2.288160 -5.934773  5.358205e-09
# 1 -0.367621 -0.487849 -0.247394  0.632989 -6.019682  3.161045e-09
# 2 -0.363231 -0.481393 -0.245068  1.419404 -6.041708  2.918153e-09
# 3 -0.361180 -0.468876 -0.253484  1.583232 -6.629935  8.291482e-11
# 4 -0.354128 -0.724176  0.015921  2.927185 -1.867562  6.228822e-02
#
#       adj.P.Val Direction hgnc_symbol  percentage_gene_gc_content  \
# 0  8.701726e-06      down       USP9Y                   38.756768
# 1  5.989127e-06      down      RPS4Y1                   40.557971
# 2  5.989127e-06      down       DDX3Y                   37.700812
# 3  6.283838e-07      down         UTY                   37.470027
# 4  2.042673e-01      none     SNORD3A                   54.220315
#
#      gene_biotype chromosome_name  gene_length
# 0  protein_coding               Y       323190
# 1  protein_coding               Y        90399
# 2  protein_coding               Y        16371
# 3  protein_coding               Y       232295
# 4          snoRNA              17          699

# %%
pd.set_option('display.max_colwidth', None)
df.sort_values(by='P.Value').head(20)
# Out:
#                                                                                          Comparison  \
# 45518   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45485   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45505   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45479   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45481   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45606   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 47329   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45477   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 46281   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 46023   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45612   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 136427      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 90952         diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP
# 45669   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45487   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45508   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45512   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 47212   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45950   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 22736   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
#
#         ensembl_gene_id     logFC      CI.L      CI.R   AveExp
# 45481  3.651596e-17  1.660454e-13        up   LINC01094
# 45482  1.549014e-07  3.276129e-06        up          CP
# 45484  1.231044e-09  7.884230e-08        up      MS4A6A
# 45486  2.336395e-10  2.299579e-08        up       APLNR
# 45487  9.369725e-15  1.563870e-11        up   LINC01088
# 45489  1.582844e-05  1.285269e-04        up       OR7A5
# 45490  2.976405e-10  2.730660e-08        up  AL390755.1
# 45491  1.441478e-10  1.656280e-08        up         C4A
# 45492  2.526168e-08  8.032862e-07        up        PIRT
# 45493  1.266870e-09  8.000988e-08        up   LINC01736
# 45494  8.597382e-09  3.441375e-07        up   C10orf105
# 45495  2.632042e-07  4.945629e-06        up        XIST
# 45496  8.250520e-08  2.010545e-06        up     ALOX15B
#
#        percentage_gene_gc_content    gene_biotype chromosome_name  gene_length
# 45472                   46.946965  protein_coding               3        49590
# 45473                   44.635575  protein_coding               1        42670
# 45474                   37.423294  protein_coding              12        33081
# 45475                   33.810418  protein_coding               1         4262
# 45476                   49.183951  protein_coding              14        31677
# 45478                   52.288596  protein_coding               6        20624
# 45480                   41.561802  protein_coding              11        93533
# 45481                   39.699590          lncRNA               4        44406
# 45482                   37.359475  protein_coding               3        59420
# 45484                   40.172291  protein_coding              11        12653
# 45486                   55.350455  protein_coding              11         3738
# 45487                   36.972195          lncRNA               4       370189
# 45489                   41.649298  protein_coding              19        11035
# 45490                   42.670164          lncRNA              13       141040
# 45491                   52.266667  protein_coding               6        20625
# 45492                   47.925471  protein_coding              17        15618
# 45493                   49.730514          lncRNA               1         4824
# 45494                   55.389680  protein_coding              10        26124
# 45495                   39.781761          lncRNA               X        32075
# 45496                   55.647956  protein_coding              17        10101

# %%
pd.set_option('display.max_colwidth', None)
df.sort_values(by='logFC').head(20)
# Out:
#                                                                                          Comparison  \
# 159152      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 45477   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45479   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 159153      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 45483   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45485   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45488   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 68208   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 113680      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
# 45498   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 159154      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 45500   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 68209   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 68210   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 22736   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 45505   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45507   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 22737   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 0         diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP
# 45510   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
#
#         ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
# 159152  ENSG00000263934 -0.558842 -0.918898 -0.198786  2.927185 -3.028957
# 45477   ENSG00000233123 -0.473508 -0.582953 -0.364064  2.281236 -8.455877
# 45479   ENSG00000223930 -0.466954 -0.570203 -0.363706  1.132420 -8.837238
# 159153  ENSG00000229807 -0.452314 -0.591995 -0.312633  6.128235 -6.308488
# 45483   ENSG00000067646 -0.425946 -0.544707 -0.307184  0.660830 -7.081323
# 45485   ENSG00000254101 -0.411177 -0.494931 -0.327423  2.229597 -9.598085
# 45488   ENSG00000147571 -0.404349 -0.552743 -0.255955  0.438421 -5.329984
# 68208   ENSG00000114374 -0.391257 -0.524079 -0.258434  2.288160 -5.786937
# 113680  ENSG00000263934 -0.388868 -0.788382  0.010646  2.927185 -1.899519
# 45498   ENSG00000164600 -0.387349 -0.505392 -0.269306  3.863586 -6.392474
# 159154  ENSG00000147571 -0.387183 -0.505196 -0.269170  0.438421 -6.417605
# 45500   ENSG00000117152 -0.383513 -0.490295 -0.276731  8.089236 -6.989785
# 68209   ENSG00000129824 -0.379796 -0.508892 -0.250699  0.632989 -5.791779
# 68210   ENSG00000165246 -0.377085 -0.499008 -0.255162  1.216907 -6.102860
# 22736   ENSG00000223930 -0.374663 -0.467533 -0.281793  1.132420 -7.882995
# 45505   ENSG00000286021 -0.373171 -0.453973 -0.292369  3.023266 -9.020301
# 45507   ENSG00000146469 -0.372809 -0.470636 -0.274983  2.306457 -7.441140
# 22737   ENSG00000012817 -0.372292 -0.483886 -0.260698  1.664448 -6.582817
# 0       ENSG00000114374 -0.371193 -0.494065 -0.248321  2.288160 -5.934773
# 45510   ENSG00000129824 -0.370549 -0.507746 -0.233353  0.632989 -5.317158
#
#              P.Value     adj.P.Val Direction hgnc_symbol  \
# 159152  2.547323e-03  2.459275e-02      down     SNORD3A
# 45477   5.376563e-16  1.394575e-12      down   LINC01007
# 45479   1.923614e-17  1.093382e-13      down  AC117453.1
# 159153  5.178791e-10  1.682071e-06      down        XIST
# 45483   4.830719e-12  1.248082e-09      down         ZFY
# 45485   8.300570e-21  9.436088e-17      down   LINC02055
# 45488   1.612477e-07  3.382037e-06      down         CRH
# 68208   1.249263e-08  6.605406e-06      down       USP9Y
# 113680  5.774870e-02  1.680188e-01      none     SNORD3A
# 45498   5.818140e-10  4.593098e-08      down     NEUROD6
# 159154  3.717468e-10  1.682071e-06      down         CRH
# 45500   1.905256e-11  3.654789e-09      down        RGS4
# 68209   1.190506e-08  6.570615e-06      down      RPS4Y1
# 68210   2.227458e-09  2.665447e-06      down      NLGN4Y
# 22736   1.493871e-14  3.396465e-10      down  AC117453.1
# 45505   2.643613e-18  2.003506e-14      down  AC112481.2
# 45507   8.853869e-13  3.470717e-10      down         VIP
# 22737   1.121767e-10  3.595518e-07      down       KDM5D
# 0       5.358205e-09  8.701726e-06      down       USP9Y
# 45510   1.618659e-07  3.388750e-06      down      RPS4Y1
#
#         percentage_gene_gc_content    gene_biotype chromosome_name  \
# 159152                   54.220315          snoRNA              17
# 45477                    48.988439          lncRNA               7
# 45479                    36.119690          lncRNA               3
# 159153                   39.781761          lncRNA               X
# 45483                    37.269724  protein_coding               Y
# 45485                    37.814757          lncRNA               8
# 45488                    55.098133  protein_coding               8
# 68208                    38.756768  protein_coding               Y
# 113680                   54.220315          snoRNA              17
# 45498                    35.438381  protein_coding               7
# 159154                   55.098133  protein_coding               8
# 45500                    39.474340  protein_coding               1
# 68209                    40.557971  protein_coding               Y
# 68210                    38.626586  protein_coding               Y
# 22736                    36.119690          lncRNA               3
# 45505                    34.923895          lncRNA              12
# 45507                    33.805329  protein_coding               6
# 22737                    38.660986  protein_coding               Y
# 0                        38.756768  protein_coding               Y
# 45510                    40.557971  protein_coding               Y
#
#         gene_length
# 159152          699
# 45477          6228
# 45479        221472
# 159153        32075
# 45483         47226
# 45485       1232815
# 45488          2089
# 68208        323190
# 113680          699
# 45498          3262
# 159154         2089
# 45500          8028
# 68209         90399
# 68210        323078
# 22736        221472
# 45505        313516
# 45507          8969
# 22737         41075
# 0            323190
# 45510         90399

# %%
df['Comparison'].value_counts()
# Out:
# diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP      22736
# diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG    22736
# diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG    22736
# diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG    22736
# diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP          22736
# diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG        22736
# diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG        22736
# diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG        22736
# Name: Comparison, dtype: int64

# %%
df['score'] = np.sign(df['logFC']) * np.exp(np.abs(df['logFC'])) * -np.log10(df['adj.P.Val'])

# %%
pd.set_option('display.max_colwidth', None)
df.sort_values(by='logFC', ascending=False).head(20)
# Out:
#                                                                                         Comparison  \
# 45472  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45473  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45474  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45475  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45476  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45478  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45480  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45481  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45482  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45484  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45486  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45487  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45489  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45490  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45491  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45492  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45493  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45494  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45495  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45496  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
#
#        ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
# 45472  ENSG00000012223  0.641804  0.406050  0.877559  1.070785  5.305905
# 45473  ENSG00000064886  0.508649  0.289374  0.727924  1.931132  4.522687
# 45474  ENSG00000177575  0.480617  0.282273  0.678961  4.136168  4.721901
# 45475  ENSG00000090104  0.480024  0.290478  0.669571  4.601565  4.931382
# 45476  ENSG00000188488  0.478775  0.326196  0.631355  0.319199  6.136612
# 45478  ENSG00000224389  0.469976  0.353313  0.586638  3.135702  7.865292
# 45480  ENSG00000026508  0.448960  0.306915  0.591005  5.514059  6.158509
# 45481  ENSG00000251442  0.439325  0.342502  0.536148  4.942249  8.851157
# 45482  ENSG00000047457  0.435381  0.277169  0.593592  5.466984  5.361016
# 45484  ENSG00000110077  0.422272  0.290404  0.554140  3.187586  6.250631
# 45486  ENSG00000134817  0.409493  0.287131  0.531856  5.897419  6.522389
# 45487  ENSG00000249307  0.404866  0.306553  0.503180  2.761845  8.041132
# 45489  ENSG00000188269  0.402078  0.222739  0.581416  0.831978  4.382697
# 45490  ENSG00000275830  0.401904  0.280636  0.523173  2.106261  6.486127
# 45491  ENSG00000244731  0.400144  0.282060  0.518228  3.253300  6.617621
# 45492  ENSG00000233670  0.398430  0.261843  0.535016  2.583642  5.693487
# 45493  ENSG00000228058  0.396709  0.272211  0.521206  0.857092  6.241551
# 45494  ENSG00000214688  0.396690  0.265447  0.527934  1.497898  5.904690
# 45495  ENSG00000229807  0.391709  0.246435  0.536983  6.128235  5.252894
# 45496  ENSG00000179593  0.389823  0.250444  0.529201  1.130888  5.476022
#
#             P.Value     adj.P.Val Direction hgnc_symbol  \
# 45472  2.048294e-07  4.054221e-06        up         LTF
# 45473  8.359895e-06  7.742182e-05        up      CHI3L2
# 45474  3.487813e-06  3.783346e-05        up       CD163
# 45475  1.271668e-06  1.695300e-05        up        RGS1
# 45476  2.052381e-09  1.135351e-07        up    SERPINA5
# 45478  4.638327e-14  4.218280e-11        up         C4B
# 45480  1.969415e-09  1.111083e-07        up        CD44
# 45481  3.651596e-17  1.660454e-13        up   LINC01094
# 45482  1.549014e-07  3.276129e-06        up          CP
# 45484  1.231044e-09  7.884230e-08        up      MS4A6A
# 45486  2.336395e-10  2.299579e-08        up       APLNR
# 45487  9.369725e-15  1.563870e-11        up   LINC01088
# 45489  1.582844e-05  1.285269e-04        up       OR7A5
# 45490  2.976405e-10  2.730660e-08        up  AL390755.1
# 45491  1.441478e-10  1.656280e-08        up         C4A
# 45492  2.526168e-08  8.032862e-07        up        PIRT
# 45493  1.266870e-09  8.000988e-08        up   LINC01736
#
#              P.Value     adj.P.Val Direction hgnc_symbol  \
# 45518   1.434571e-21  3.261641e-17        up        CAPS
# 45481   3.651596e-17  1.660454e-13        up   LINC01094
# 45478   4.638327e-14  4.218280e-11        up         C4B
# 45487   9.369725e-15  1.563870e-11        up   LINC01088
# 45606   4.113946e-16  1.394575e-12        up     IL13RA1
# 45508   9.918798e-15  1.563870e-11        up        GMPR
# 45512   1.087301e-14  1.563870e-11        up      CLEC7A
# 45519   1.729804e-14  2.069938e-11        up     GALNT15
# 45628   1.651221e-14  2.069938e-11        up       WDR49
# 45511   5.600095e-13  2.448534e-10        up       MS4A7
# 136427  2.482705e-15  5.644679e-11        up       MS4A7
# 45564   2.628452e-13  1.494012e-10        up       ITPKB
# 45561   4.083789e-13  2.018457e-10        up      STEAP3
# 45574   3.334664e-13  1.784307e-10        up      PHYHD1
# 45665   1.593376e-13  1.132094e-10        up       AHNAK
# 45506   5.474385e-12  1.352887e-09        up        FPR3
# 45526   2.965442e-12  8.989638e-10        up     SIGLEC8
# 45520   4.594200e-12  1.214578e-09        up      ADORA3
# 46672   3.612096e-14  3.421859e-11      none        DDB2
# 45737   5.264562e-13  2.442757e-10      none       CSRP1
#
#         percentage_gene_gc_content    gene_biotype chromosome_name  \
# 45518                    57.095270  protein_coding              19
# 45481                    39.699590          lncRNA               4
# 45478                    52.288596  protein_coding               6
# 45487                    36.972195          lncRNA               4
# 45606                    40.566444  protein_coding               X
# 45508                    47.826926  protein_coding               6
# 45512                    37.420264  protein_coding              12
# 45519                    45.631881  protein_coding               3
# 45628                    36.513976  protein_coding               3
# 45511                    40.711055  protein_coding              11
# 136427                   40.711055  protein_coding              11
# 45564                    49.820689  protein_coding               1
# 45561                    51.668978  protein_coding               2
# 45574                    51.561017  protein_coding               9
# 45665                    50.052977  protein_coding              11
# 45506                    42.762776  protein_coding              19
# 45526                    51.852825  protein_coding              19
# 45520                    39.635272  protein_coding               1
# 46672                    47.154504  protein_coding              11
# 45737                    50.684614  protein_coding               1
#
#         gene_length      score
# 45518          4503  23.587967
# 45481         44406  19.829860
# 45478         20624  16.599321
# 45487        370189  16.198995
# 45606         67403  15.861280
# 45508         56970  15.686537
# 45512         13482  15.576135
# 45519         57313  15.252373
# 45628        175300  14.133418
# 45511         17467  13.899767
# 136427        17467  13.458432
# 45564        107634  13.445185
# 45561         41822  13.295684
# 45574         21076  13.274999
# 45665        122694  12.989771
# 45506         31034  12.877183
# 45526          7610  12.821685
# 45520          4332  12.718541
# 46672         24776  12.390594
# 45737         25927  12.349319

# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.contains('SNORD3A')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='adj.P.Val')

# Display the first 20 rows
df_filtered.head(20)
# Out:
#                                                                                          Comparison  \
# 159152      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 113680      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
# 4         diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP
# 90949         diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP
# 22740   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 68259   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 136630      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 52701   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
#
#         ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
# 159152  ENSG00000263934 -0.558842 -0.918898 -0.198786  2.927185 -3.028957
# 113680  ENSG00000263934 -0.388868 -0.788382  0.010646  2.927185 -1.899519
# 4       ENSG00000263934 -0.354128 -0.724176  0.015921  2.927185 -1.867562
# 90949   ENSG00000263934  0.258889 -0.078723  0.596502  2.927185  1.496475
# 22740   ENSG00000263934 -0.345767 -0.857417  0.165883  2.927185 -1.318818
# 68259   ENSG00000263934 -0.246856 -0.647322  0.153609  2.927185 -1.202965
# 136630  ENSG00000263934 -0.170047 -0.576396  0.236302  2.927185 -0.816666
# 52701   ENSG00000263934 -0.068761 -0.557048  0.419525  2.927185 -0.274817
#
#          P.Value  adj.P.Val Direction hgnc_symbol  percentage_gene_gc_content  \
# 159152  0.002547   0.024593      down     SNORD3A                   54.220315
# 113680  0.057749   0.168019      none     SNORD3A                   54.220315
# 4       0.062288   0.204267      none     SNORD3A                   54.220315
# 90949   0.134945   0.302978      none     SNORD3A                   54.220315
# 22740   0.187502   0.363618      none     SNORD3A                   54.220315
# 68259   0.229460   0.406561      none     SNORD3A                   54.220315
# 136630  0.414291   0.564572      none     SNORD3A                   54.220315
# 52701   0.783528   0.850203      none     SNORD3A                   54.220315
#
#        gene_biotype chromosome_name  gene_length     score
# 159152       snoRNA              17          699 -2.813910
# 113680       snoRNA              17          699 -1.142837
# 4            snoRNA              17          699 -0.982923
# 90949        snoRNA              17          699  0.671828
# 22740        snoRNA              17          699 -0.620841
# 68259        snoRNA              17          699 -0.500317
# 136630       snoRNA              17          699 -0.294302
# 52701        snoRNA              17          699 -0.075494

# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.contains('XIST')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='logFC', ascending=False)

# Display the first 20 rows
df_filtered.head(20)
# Out:
#                                                                                          Comparison  \
# 45495   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 68212   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 10        diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP
# 22753   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 113756      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
# 136524      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 90954         diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP
# 159153      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
#
#         ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
# 45495   ENSG00000229807  0.391709  0.246435  0.536983  6.128235  5.252894
# 68212   ENSG00000229807  0.360235  0.227096  0.493374  6.128235  5.271152
# 10      ENSG00000229807  0.322082  0.199610  0.444555  6.128235  5.123324
# 22753   ENSG00000229807  0.299521  0.176331  0.422712  6.128235  4.736692
# 113756  ENSG00000229807 -0.171564 -0.292623 -0.050505  6.128235 -2.760915
# 136524  ENSG00000229807 -0.197778 -0.327211 -0.068344  6.128235 -2.976829
# 90954   ENSG00000229807 -0.239805 -0.365411 -0.114200  6.128235 -3.719425
# 159153  ENSG00000229807 -0.452314 -0.591995 -0.312633  6.128235 -6.308488
#
#              P.Value  adj.P.Val Direction hgnc_symbol  \
# 45495   2.632042e-07   0.000005        up        XIST
# 68212   2.372613e-07   0.000050        up        XIST
# 10      4.964821e-07   0.000179        up        XIST
# 22753   3.106471e-06   0.000355        up        XIST
# 113756  5.891738e-03   0.042032      none        XIST
# 136524  2.990020e-03   0.014455      none        XIST
# 90954   2.166165e-04   0.006586      none        XIST
# 159153  5.178791e-10   0.000002      down        XIST
#
#         percentage_gene_gc_content gene_biotype chromosome_name  gene_length  \
# 45495                    39.781761       lncRNA               X        32075
# 68212                    39.781761       lncRNA               X        32075
# 10                       39.781761       lncRNA               X        32075
# 22753                    39.781761       lncRNA               X        32075
# 113756                   39.781761       lncRNA               X        32075
# 136524                   39.781761       lncRNA               X        32075
# 90954                    39.781761       lncRNA               X        32075
# 159153                   39.781761       lncRNA               X        32075
#
#            score
# 45495   7.849935
# 68212   6.161099
# 10      5.170472
# 22753   4.654611
# 113756 -1.634036
# 136524 -2.242376
# 90954  -2.772527
# 159153 -9.076657

# %%
df['gene_biotype'].value_counts()
# Out:
# protein_coding                        121736
# lncRNA                                 39896
# processed_pseudogene                    9272
# TEC                                     3008
# transcribed_unprocessed_pseudogene      2640
# unprocessed_pseudogene                  1456
# misc_RNA                                1296
# transcribed_processed_pseudogene        1120
# snoRNA                                   440
# transcribed_unitary_pseudogene           384
# snRNA                                    216
# miRNA                                    192
# unitary_pseudogene                        48
# polymorphic_pseudogene                    40
# rRNA_pseudogene                           40
# scaRNA                                    40
# TR_C_gene                                 24
# Mt_tRNA                                   16
# Mt_rRNA                                   16
# translated_unprocessed_pseudogene          8
# Name: gene_biotype, dtype: int64

# %%
df_sig = df[df['adj.P.Val'] < 0.05]
df_sig.sort_values(by='logFC', ascending=False).head(20)
# Out:
#                                                                                         Comparison  \
# 45472  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45473  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45474  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45475  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45476  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45478  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45480  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45481  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45482  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45484  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45486  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45487  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45489  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45490  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45491  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45492  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45493  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45494  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45495  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45496  diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
#
#        ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
# 45472  ENSG00000012223  0.641804  0.406050  0.877559  1.070785  5.305905
# 45473  ENSG00000064886  0.508649  0.289374  0.727924  1.931132  4.522687
# 45474  ENSG00000177575  0.480617  0.282273  0.678961  4.136168  4.721901
# 45475  ENSG00000090104  0.480024  0.290478  0.669571  4.601565  4.931382
# 45476  ENSG00000188488  0.478775  0.326196  0.631355  0.319199  6.136612
# 45478  ENSG00000224389  0.469976  0.353313  0.586638  3.135702  7.865292
# 45480  ENSG00000026508  0.448960  0.306915  0.591005  5.514059  6.158509
# 45481  ENSG00000251442  0.439325  0.342502  0.536148  4.942249  8.851157
# 45482  ENSG00000047457  0.435381  0.277169  0.593592  5.466984  5.361016
# 45484  ENSG00000110077  0.422272  0.290404  0.554140  3.187586  6.250631
# 45486  ENSG00000134817  0.409493  0.287131  0.531856  5.897419  6.522389
# 45487  ENSG00000249307  0.404866  0.306553  0.503180  2.761845  8.041132
# 45489  ENSG00000188269  0.402078  0.222739  0.581416  0.831978  4.382697
# 45490  ENSG00000275830  0.401904  0.280636  0.523173  2.106261  6.486127
# 45491  ENSG00000244731  0.400144  0.282060  0.518228  3.253300  6.617621
# 45492  ENSG00000233670  0.398430  0.261843  0.535016  2.583642  5.693487
# 45493  ENSG00000228058  0.396709  0.272211  0.521206  0.857092  6.241551
# 45494  ENSG00000214688  0.396690  0.265447  0.527934  1.497898  5.904690
# 45495  ENSG00000229807  0.391709  0.246435  0.536983  6.128235  5.252894
# 45496  ENSG00000179593  0.389823  0.250444  0.529201  1.130888  5.476022
#
#             P.Value     adj.P.Val Direction hgnc_symbol  \
# 45472  2.048294e-07  4.054221e-06        up         LTF
# 45473  8.359895e-06  7.742182e-05        up      CHI3L2
# 45474  3.487813e-06  3.783346e-05        up       CD163
# 45475  1.271668e-06  1.695300e-05        up        RGS1
# 45476  2.052381e-09  1.135351e-07        up    SERPINA5
# 45478  4.638327e-14  4.218280e-11        up         C4B
# 45480  1.969415e-09  1.111083e-07        up        CD44
# 45481  3.651596e-17  1.660454e-13        up   LINC01094
# 45482  1.549014e-07  3.276129e-06        up          CP
# 45484  1.231044e-09  7.884230e-08        up      MS4A6A
# 45486  2.336395e-10  2.299579e-08        up       APLNR
# 45487  9.369725e-15  1.563870e-11        up   LINC01088
# 45489  1.582844e-05  1.285269e-04        up       OR7A5
# 45490  2.976405e-10  2.730660e-08        up  AL390755.1
# 45491  1.441478e-10  1.656280e-08        up         C4A
# 45492  2.526168e-08  8.032862e-07        up        PIRT
# 45493  1.266870e-09  8.000988e-08        up   LINC01736
# 45494  8.597382e-09  3.441375e-07        up   C10orf105
# 45495  2.632042e-07  4.945629e-06        up        XIST
# 45496  8.250520e-08  2.010545e-06        up     ALOX15B
#
#        percentage_gene_gc_content    gene_biotype chromosome_name  \
# 45472                   46.946965  protein_coding               3
# 45473                   44.635575  protein_coding               1
# 45474                   37.423294  protein_coding              12
# 45475                   33.810418  protein_coding               1
# 45476                   49.183951  protein_coding              14
# 45478                   52.288596  protein_coding               6
# 45480                   41.561802  protein_coding              11
# 45481                   39.699590          lncRNA               4
# 45482                   37.359475  protein_coding               3
# 45484                   40.172291  protein_coding              11
# 45486                   55.350455  protein_coding              11
# 45487                   36.972195          lncRNA               4
# 45489                   41.649298  protein_coding              19
# 45490                   42.670164          lncRNA              13
# 45491                   52.266667  protein_coding               6
# 45492                   47.925471  protein_coding              17
# 45493                   49.730514          lncRNA               1
# 45494                   55.389680  protein_coding              10
# 45495                   39.781761          lncRNA               X
# 45496                   55.647956  protein_coding              17
#
#        gene_length      score
# 45472        49590  10.244467
# 45473        42670   6.836997
# 45474        33081   7.150894
# 45475         4262   7.710081
# 45476        31677  11.209691
# 45478        20624  16.599321
# 45480        93533  10.895104
# 45481        44406  19.829860
# 45482        59420   8.476790
# 45484        12653  10.835450
# 45486         3738  11.503775
# 45487       370189  16.198995
# 45489        11035   5.816771
# 45490       141040  11.305271
# 45491        20625  11.609358
# 45492        15618   9.078600
# 45493         4824  10.552477
# 45494        26124   9.610205
# 45495        32075   7.849935
# 45496        10101   8.412405

# %%
# Define the function to apply to each group
def filter_func(group):
    return group[group['logFC'].abs() >= 0.2].shape[0] >= 4

# Group the data by the gene id, and then apply the function to each group
df_filtered = df.groupby('ensembl_gene_id').filter(filter_func)

# Now df_filtered will contain only the rows for genes where at least 4 comparisons 
# have a logFC value of .2 or higher or a -.2 or lower

# %%
df_filtered.sort_values(by='logFC')
# Out:
#                                                                                          Comparison  \
# 159152      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 45477   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45479   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 159153      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 45483   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# ...                                                                                             ...
# 45476   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45475   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45474   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45473   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45472   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
#
#         ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
# 159152  ENSG00000263934 -0.558842 -0.918898 -0.198786  2.927185 -3.028957
# 45477   ENSG00000233123 -0.473508 -0.582953 -0.364064  2.281236 -8.455877
# 45479   ENSG00000223930 -0.466954 -0.570203 -0.363706  1.132420 -8.837238
# 159153  ENSG00000229807 -0.452314 -0.591995 -0.312633  6.128235 -6.308488
# 45483   ENSG00000067646 -0.425946 -0.544707 -0.307184  0.660830 -7.081323
# ...                 ...       ...       ...       ...       ...       ...
# 45476   ENSG00000188488  0.478775  0.326196  0.631355  0.319199  6.136612
# 45475   ENSG00000090104  0.480024  0.290478  0.669571  4.601565  4.931382
# 45474   ENSG00000177575  0.480617  0.282273  0.678961  4.136168  4.721901
# 45473   ENSG00000064886  0.508649  0.289374  0.727924  1.931132  4.522687
# 45472   ENSG00000012223  0.641804  0.406050  0.877559  1.070785  5.305905
#
#              P.Value     adj.P.Val Direction hgnc_symbol  \
# 159152  2.547323e-03  2.459275e-02      down     SNORD3A
# 45477   5.376563e-16  1.394575e-12      down   LINC01007
# 45479   1.923614e-17  1.093382e-13      down  AC117453.1
# 159153  5.178791e-10  1.682071e-06      down        XIST
# 45483   4.830719e-12  1.248082e-09      down         ZFY
# ...              ...           ...       ...         ...
# 45476   2.052381e-09  1.135351e-07        up    SERPINA5
# 45475   1.271668e-06  1.695300e-05        up        RGS1
# 45474   3.487813e-06  3.783346e-05        up       CD163
# 45473   8.359895e-06  7.742182e-05        up      CHI3L2
# 45472   2.048294e-07  4.054221e-06        up         LTF
#
#         percentage_gene_gc_content    gene_biotype chromosome_name  \
# 159152                   54.220315          snoRNA              17
# 45477                    48.988439          lncRNA               7
# 45479                    36.119690          lncRNA               3
# 159153                   39.781761          lncRNA               X
# 45483                    37.269724  protein_coding               Y
# ...                            ...             ...             ...
# 45476                    49.183951  protein_coding              14
# 45475                    33.810418  protein_coding               1
# 45474                    37.423294  protein_coding              12
# 45473                    44.635575  protein_coding               1
# 45472                    46.946965  protein_coding               3
#
#         gene_length      score
# 159152          699  -2.813910
# 45477          6228 -19.035492
# 45479        221472 -20.674823
# 159153        32075  -9.076657
# 45483         47226 -13.631989
# ...             ...        ...
# 45476         31677  11.209691
# 45475          4262   7.710081
# 45474         33081   7.150894
# 45473         42670   6.836997
# 45472         49590  10.244467
#
# [680 rows x 16 columns]

# %%
# Define the function to apply to each group
def filter_func(group):
    # Add condition for adjusted p-value
    condition_met = group[(group['logFC'].abs() >= 0.2) & (group['adj.P.Val'] < 0.05)].shape[0]
    return condition_met >= 4

# Group the data by the gene id, and then apply the function to each group
df_filtered2 = df.groupby('ensembl_gene_id').filter(filter_func)

# %%
df_filtered2.sort_values(by='logFC', ascending=False).head(30)
# Out:
#                                                                                          Comparison  \
# 45472   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45474   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45475   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45476   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45478   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45480   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45481   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45482   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45484   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45491   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45493   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45495   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45496   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45501   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45502   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45504   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45506   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45511   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45512   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 22738   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 45515   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45516   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 68212   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 45520   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 68213   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 45525   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45526   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45528   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 136416      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 68215   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
#
#         ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
# 45472   ENSG00000012223  0.641804  0.406050  0.877559  1.070785  5.305905
# 45474   ENSG00000177575  0.480617  0.282273  0.678961  4.136168  4.721901
# 45475   ENSG00000090104  0.480024  0.290478  0.669571  4.601565  4.931382
# 45476   ENSG00000188488  0.478775  0.326196  0.631355  0.319199  6.136612
# 45478   ENSG00000224389  0.469976  0.353313  0.586638  3.135702  7.865292
# 45480   ENSG00000026508  0.448960  0.306915  0.591005  5.514059  6.158509
# 45481   ENSG00000251442  0.439325  0.342502  0.536148  4.942249  8.851157
# 45482   ENSG00000047457  0.435381  0.277169  0.593592  5.466984  5.361016
# 1       3.161045e-09  5.989127e-06      down      RPS4Y1
# 22739   8.817055e-09  6.912571e-06      down       USP9Y
# 2       2.918153e-09  5.989127e-06      down       DDX3Y
# 68211   4.740231e-09  4.314872e-06      down       KDM5D
# 3       8.291482e-11  6.283838e-07      down         UTY
# 45521   4.939982e-08  1.345095e-06      down     PCDH11Y
# 90945   7.046839e-11  8.010846e-07      down       KLRC2
# 5       1.167468e-10  6.635886e-07      down      TXLNGY
# 6       3.156229e-10  1.435200e-06      down     PCDH11Y
# 68214   7.107729e-09  5.771476e-06      down     PCDH11Y
# 45527   3.239086e-14  3.333703e-11      down       PPEF1
# 45529   2.448046e-06  2.861633e-05      down       USP9Y
# 68216   3.280098e-09  3.389832e-06      down         ZFY
# 68217   9.346753e-07  1.336903e-04      down         CRH
# 68218   1.070485e-08  6.463989e-06      down         UTY
# 22741   8.733265e-08  2.907972e-05      down         CRH
#
#         percentage_gene_gc_content                        gene_biotype  \
# 45477                    48.988439                              lncRNA
# 45479                    36.119690                              lncRNA
# 159153                   39.781761                              lncRNA
# 45483                    37.269724                      protein_coding
# 45488                    55.098133                      protein_coding
# 68208                    38.756768                      protein_coding
# 159154                   55.098133                      protein_coding
# 68209                    40.557971                      protein_coding
# 68210                    38.626586                      protein_coding
# 22736                    36.119690                              lncRNA
# 45507                    33.805329                      protein_coding
# 22737                    38.660986                      protein_coding
# 0                        38.756768                      protein_coding
# 45510                    40.557971                      protein_coding
# 1                        40.557971                      protein_coding
# 22739                    38.756768                      protein_coding
# 2                        37.700812                      protein_coding
# 68211                    38.660986                      protein_coding
# 3                        37.470027                      protein_coding
# 45521                    35.661908                      protein_coding
# 90945                    33.527546                      protein_coding
# 5                        36.420102  transcribed_unprocessed_pseudogene
# 6                        35.661908                      protein_coding
# 68214                    35.661908                      protein_coding
# 45527                    41.706959                      protein_coding
# 45529                    38.756768                      protein_coding
# 68216                    37.269724                      protein_coding
# 68217                    55.098133                      protein_coding
# 68218                    37.470027                      protein_coding
# 22741                    55.098133                      protein_coding
#
#        chromosome_name  gene_length      score
# 45477                7         6228 -19.035492
# 45479                3       221472 -20.674823
# 159153               X        32075  -9.076657
# 45483                Y        47226 -13.631989
# 45488                8         2089  -8.197078
# 68208                Y       323190  -7.660529
# 159154               8         2089  -8.504327
# 68209                Y        90399  -7.576586
# 68210                Y       323078  -8.127383
# 22736                3       221472 -13.772628
# 45507                6         8969 -13.733492
# 22737                Y        41075  -9.350954
# 0                    Y       323190  -7.334851
# 45510                Y        90399  -7.923403
# 1                    Y        90399  -7.543026
# 22739                Y       323190  -7.426008
# 2                    Y        16371  -7.509982
# 68211                Y        41075  -7.707246
# 3                    Y       232295  -8.899680
# 45521                Y       741999  -8.331072
# 90945               12        15447  -8.647611
# 5                    Y        38962  -8.763227
# 6                    Y       741999  -8.264670
# 68214                Y       741999  -7.405229
# 45527                X       152013 -14.803530
# 45529                Y       323190  -6.412317
# 68216                Y        47226  -7.687008
# 68217                8         2089  -5.440894
# 68218                Y       232295  -7.288027
# 22741                8         2089  -6.352633

# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.contains('XIST')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='logFC')

# Display the first 20 rows
df_filtered.head(20)
# Out:
#                                                                                          Comparison  \
# 159153      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 90954         diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP
# 136524      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 113756      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
# 22753   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 10        diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP
# 68212   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 45495   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
#
#         ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
# 159153  ENSG00000229807 -0.452314 -0.591995 -0.312633  6.128235 -6.308488
# 90954   ENSG00000229807 -0.239805 -0.365411 -0.114200  6.128235 -3.719425
# 136524  ENSG00000229807 -0.197778 -0.327211 -0.068344  6.128235 -2.976829
# 113756  ENSG00000229807 -0.171564 -0.292623 -0.050505  6.128235 -2.760915
# 22753   ENSG00000229807  0.299521  0.176331  0.422712  6.128235  4.736692
# 10      ENSG00000229807  0.322082  0.199610  0.444555  6.128235  5.123324
# 68212   ENSG00000229807  0.360235  0.227096  0.493374  6.128235  5.271152
# 45495   ENSG00000229807  0.391709  0.246435  0.536983  6.128235  5.252894
#
#              P.Value  adj.P.Val Direction hgnc_symbol  \
# 159153  5.178791e-10   0.000002      down        XIST
# 90954   2.166165e-04   0.006586      none        XIST
# 136524  2.990020e-03   0.014455      none        XIST
# 113756  5.891738e-03   0.042032      none        XIST
# 22753   3.106471e-06   0.000355        up        XIST
# 10      4.964821e-07   0.000179        up        XIST
# 68212   2.372613e-07   0.000050        up        XIST
# 45495   2.632042e-07   0.000005        up        XIST
#
#         percentage_gene_gc_content gene_biotype chromosome_name  gene_length  \
# 159153                   39.781761       lncRNA               X        32075
# 90954                    39.781761       lncRNA               X        32075
# 136524                   39.781761       lncRNA               X        32075
# 113756                   39.781761       lncRNA               X        32075
# 22753                    39.781761       lncRNA               X        32075
# 10                       39.781761       lncRNA               X        32075
# 68212                    39.781761       lncRNA               X        32075
# 45495                    39.781761       lncRNA               X        32075
#
#            score
# 159153 -9.076657
# 90954  -2.772527
# 136524 -2.242376
# 113756 -1.634036
# 22753   4.654611
# 10      5.170472
# 68212   6.161099
# 45495   7.849935

# %%
# Define the function to apply to each group
def filter_func(group):
    # Add condition for adjusted p-value
    condition_met = group[(group['logFC'].abs() >= 0.2) & (group['adj.P.Val'] < 0.05)].shape[0]
    return condition_met >= 4

# Define the list of comparisons of interest
comparisons = [
    'diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP',
    'diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG',
    'diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG',
    'diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG',
    'diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP',
    'diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG',
    'diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG',
    'diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG'
]

# Filter the dataframe based on comparisons and p-value
df_filtered3 = df[df['Comparison'].isin(comparisons) & (df['adj.P.Val'] < 0.05)]

# Exclude rows where the comparison is between two females and the chromosome is Y
df_filtered3 = df_filtered3[~((df_filtered3['chromosome_name'] == 'Y') & (df_filtered3['Comparison'].str.contains('female')))]

# Group the filtered data by the gene id, and then apply the function to each group
df_filtered3 = df_filtered3.groupby('ensembl_gene_id').filter(filter_func)

# %%
df_filtered3.sort_values(by='logFC').head(30)
# Out:
#                                                                                          Comparison  \
# 45477   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 45479   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 159153      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 45488   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 159154      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 22736   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 45507   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 90945         diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP
# 45527   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 68217   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 22741   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 11        diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP
# 45577   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 113682      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
# 159157      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 68229   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 45608   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 159158      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 113683      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
# 113684      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
# 22758   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 90947         diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP
# 136424      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 68232   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 19        diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP
# 22761   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 68235   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 136428      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 113686      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
# 68239   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
#
#         ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
# 
# 22741   8.733265e-08  2.907972e-05      down         CRH
# 11      4.388439e-07  1.750448e-04      down         CRH
# 45577   4.293090e-08  1.215691e-06      down   LINC01844
# 113682  7.342294e-10  1.669344e-06      down         CRH
# 159157  1.052697e-10  1.196706e-06      down   LINC01844
# 68229   8.396786e-10  1.735539e-06      down         VIP
# 45608   1.500135e-10  1.671916e-08      down  AC034268.2
# 159158  9.424980e-07  2.521016e-04      down       KLRC2
# 113683  7.702993e-08  4.733385e-05      down  AC011379.2
# 113684  8.931531e-14  1.015336e-09      down        KRT5
# 22758   1.931220e-09  2.310959e-06      down   LINC01007
# 90947   1.770210e-07  1.916548e-04      down         CRH
# 136424  1.406078e-07  1.041322e-05      down         CRH
# 68232   6.252181e-08  1.870389e-05      down   LINC01007
# 19      2.288086e-09  5.202193e-06      down   LINC01844
# 22761   7.588849e-09  6.390373e-06      down   LINC01844
# 68235   6.955435e-08  2.027420e-05      down   LINC01844
# 136428  6.448415e-12  1.267437e-08      down   LINC01844
# 113686  8.719500e-12  4.956164e-08      down   LINC01844
# 68239   2.255472e-07  4.961349e-05      down  AC117453.1
#
#         percentage_gene_gc_content    gene_biotype chromosome_name  \
# 45477                    48.988439          lncRNA               7
# 45479                    36.119690          lncRNA               3
# 159153                   39.781761          lncRNA               X
# 45488                    55.098133  protein_coding               8
# 159154                   55.098133  protein_coding               8
# 22736                    36.119690          lncRNA               3
# 45507                    33.805329  protein_coding               6
# 90945                    33.527546  protein_coding              12
# 45527                    41.706959  protein_coding               X
# 68217                    55.098133  protein_coding               8
# 22741                    55.098133  protein_coding               8
# 11                       55.098133  protein_coding               8
# 45577                    43.977504          lncRNA               5
# 113682                   55.098133  protein_coding               8
# 159157                   43.977504          lncRNA               5
# 68229                    33.805329  protein_coding               6
# 45608                    36.258891          lncRNA              17
# 159158                   33.527546  protein_coding              12
# 113683                   45.223416          lncRNA               5
# 113684                   50.805910  protein_coding              12
# 22758                    48.988439          lncRNA               7
# 90947                    55.098133  protein_coding               8
# 136424                   55.098133  protein_coding               8
# 68232                    48.988439          lncRNA               7
# 19                       43.977504          lncRNA               5
# 22761                    43.977504          lncRNA               5
# 68235                    43.977504          lncRNA               5
# 136428                   43.977504          lncRNA               5
# 113686                   43.977504          lncRNA               5
# 68239                    36.119690          lncRNA               3
#
#         gene_length      score
# 45477          6228 -19.035492
# 45479        221472 -20.674823
# 159153        32075  -9.076657
# 45488          2089  -8.197078
# 159154         2089  -8.504327
# 22736        221472 -13.772628
# 45507          8969 -13.733492
# 90945         15447  -8.647611
# 45527        152013 -14.803530
# 68217          2089  -5.440894
# 22741          2089  -6.352633
# 11             2089  -5.161011
# 45577         44807  -8.033488
# 113682         2089  -7.834878
# 159157        44807  -7.970231
# 68229          8969  -7.705325
# 45608       1088875 -10.399927
# 159158        15447  -4.808484
# 113683        15733  -5.776133
# 113684         5956 -11.984828
# 22758          6228  -7.477934
# 90947          2089  -4.926414
# 136424         2089  -6.601286
# 68232          6228  -6.263086
# 19            44807  -6.986110
# 22761         44807  -6.861610
# 68235         44807  -6.189527
# 136428        44807 -10.365828
# 113686        44807  -9.545069
# 68239        221472  -5.621945

# %%
df_filtered3.sort_values(by='logFC', ascending=False).head(30)
# Out:
#                                                                                          Comparison  \
# 45472   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 
#
#              P.Value     adj.P.Val Direction hgnc_symbol  \
# 45472   2.048294e-07  4.054221e-06        up         LTF
# 45474   3.487813e-06  3.783346e-05        up       CD163
# 45475   1.271668e-06  1.695300e-05        up        RGS1
# 45476   2.052381e-09  1.135351e-07        up    SERPINA5
# 45478   4.638327e-14  4.218280e-11        up         C4B
# 45480   1.969415e-09  1.111083e-07        up        CD44
# 45481   3.651596e-17  1.660454e-13        up   LINC01094
# 45482   1.549014e-07  3.276129e-06        up          CP
# 45484   1.231044e-09  7.884230e-08        up      MS4A6A
# 45491   1.441478e-10  1.656280e-08        up         C4A
# 45493   1.266870e-09  8.000988e-08        up   LINC01736
# 45495   2.632042e-07  4.945629e-06        up        XIST
# 45496   8.250520e-08  2.010545e-06        up     ALOX15B
# 45501   1.737663e-07  3.562444e-06        up        SCIN
# 45502   1.205831e-07  2.733378e-06        up      CLEC4E
# 45504   5.469908e-06  5.442619e-05        up    HLA-DQA2
# 45506   5.474385e-12  1.352887e-09        up        FPR3
# 45511   5.600095e-13  2.448534e-10        up       MS4A7
# 45512   1.087301e-14  1.563870e-11        up      CLEC7A
# 22738   4.081459e-04  8.513399e-03        up         LTF
# 45515   1.909100e-06  2.348771e-05        up  AL929091.1
# 45516   3.237861e-08  9.828573e-07        up        MSR1
# 68212   2.372613e-07  5.041470e-05        up        XIST
# 45520   4.594200e-12  1.214578e-09        up      ADORA3
# 68213   1.697302e-04  3.583088e-03        up       CD163
# 45525   3.011015e-05  2.174665e-04        up        PCK1
# 45526   2.965442e-12  8.989638e-10        up     SIGLEC8
# 45528   9.029266e-09  3.588975e-07        up     HLA-DRA
# 136416  4.766014e-10  1.970183e-07        up    SERPINA5
# 68215   1.108795e-08  6.463989e-06        up   LINC01736
#
#         percentage_gene_gc_content    gene_biotype chromosome_name  \
# 45472                    46.946965  protein_coding               3
# 45474                    37.423294  protein_coding              12
# 45475                    33.810418  protein_coding               1
# 45476                    49.183951  protein_coding              14
# 45478                    52.288596  protein_coding               6
# 45480                    41.561802  protein_coding              11
# 45481                    39.699590          lncRNA               4
# 45482                    37.359475  protein_coding               3
# 45484                    40.172291  protein_coding              11
# 45491                    52.266667  protein_coding               6
# 45493                    49.730514          lncRNA               1
# 45495                    39.781761          lncRNA               X
# 45496                    55.647956  protein_coding              17
# 45501                    38.457246  protein_coding               7
# 45502                    39.783262  protein_coding              12
# 45504                    43.139258  protein_coding               6
# 45506                    42.762776  protein_coding              19
# 45511                    40.711055  protein_coding              11
# 45512                    37.420264  protein_coding              12
# 22738                    46.946965  protein_coding               3
# 45515                    45.568737          lncRNA               1
# 45516                    35.520101  protein_coding               8
# 68212                    39.781761          lncRNA               X
# 45520                    39.635272  protein_coding               1
# 68213                    37.423294  protein_coding              12
# 45525                    48.324340  protein_coding              20
# 45526                    51.852825  protein_coding              19
# 45528                    42.909654  protein_coding               6
# 136416                   49.183951  protein_coding              14
# 68215                    49.730514          lncRNA               1
#
#         gene_length      score
# 45472         49590  10.244467
# 45474         33081   7.150894
# 45475          4262   7.710081
# 45476         31677  11.209691
# 45478         20624  16.599321
# 45480         93533  10.895104
# 45481         44406  19.829860
# 45482         59420   8.476790
# 45484         12653  10.835450
# 45491         20625  11.609358
# 45493          4824  10.552477
# 45495         32075   7.849935
# 45496         10101   8.412405
# 45501         89606   7.990764
# 45502          7659   8.144513
# 45504          5874   6.218062
# 45506         31034  12.877183
# 45511         17467  13.899767
# 45512         13482  15.576135
# 22738         49590   2.979572
# 45515         11464   6.650842
# 45516        459613   8.619659
# 68212         32075   6.161099
# 45520          4332  12.718541
# 68213         33081   3.486354
# 45525          7042   5.191810
# 45526          7610  12.821685
# 45528          5169   9.096247
# 136416        31677   9.453021
# 68215          4824   7.313472

# %%
# Group by 'ensembl_gene_id' and 'Comparison', then calculate the mean logFC for each group
df_grouped = df_filtered3.groupby(['hgnc_symbol', 'Comparison'])['logFC'].mean().reset_index()

# Regroup by 'ensembl_gene_id', calculate the mean of the mean logFCs, and sort
df_grouped = df_grouped.groupby('hgnc_symbol')['logFC'].mean().sort_values(ascending=False)

# Convert back to DataFrame
df_grouped = df_grouped.reset_index()

df_grouped.head(30)
# Out:
#    hgnc_symbol     logFC
# 0          LTF  0.370818
# 1         RGS1  0.329475
# 2        CD163  0.321395
# 3       MS4A6A  0.299194
# 4     SERPINA5  0.289724
# 5           CP  0.288993
# 6     HLA-DQA2  0.275038
# 7         SCIN  0.273214
# 8        FCGBP  0.272295
# 9    LINC01736  0.266137
# 10        PCK1  0.264353
# 11         C4B  0.262782
# 12        CD44  0.251483
# 13   LINC01094  0.245288
# 14      CLEC4E  0.243605
# 15       MS4A7  0.242618
# 16  AL929091.1  0.239912
# 17       VSIG4  0.238299
# 18      ADORA3  0.236963
# 19        MSR1  0.233487
# 20        FPR3  0.231069
# 21        C1QA  0.227446
# 22     ALOX15B  0.225899
# 23     SIGLEC8  0.224998
# 24         C4A  0.224131
# 25     HLA-DRA  0.222956
# 26      S100A4  0.218356
# 27   LINC02432  0.217958
# 28      CLEC5A  0.216864
# 29        C1QB  0.215841

# %%
df_grouped.tail(30)
# Out:
#    hgnc_symbol     logFC
# 32       CYTL1  0.211157
# 33          C3  0.210444
# 34     HERC2P3  0.210437
# 35      FCGR2A  0.208696
# 36     FAM177B  0.208052
# 37        C1QC  0.205602
# 38       HCLS1  0.203836
# 39       FKBP5  0.201566
# 40        CD86  0.201219
# 41      MS4A4A  0.200671
# 42    HLA-DPA1  0.197001
# 43      SIRPB2  0.195626
# 44      RNASE6  0.192855
# 45        XIST  0.039011
# 46   LINC02427 -0.186282
# 47     SLC28A2 -0.200901
# 48  AC007424.1 -0.205180
# 49  AC034268.2 -0.211380
# 50        KRT5 -0.212149
# 51   SPRY4-AS1 -0.216798
# 52       PPEF1 -0.218902
# 53    Z74021.1 -0.220478
# 54  AC051619.5 -0.224267
# 55         VIP -0.224741
# 56       KLRC2 -0.235502
# 57   LINC01007 -0.250271
# 58  AC011379.2 -0.250368
# 59  AC117453.1 -0.255026
# 60   LINC01844 -0.279258
# 61         CRH -0.331629

# %%
# Define function to determine gender based on 'Comparison'
def get_gender(comparison_str):
    if 'female' in comparison_str:
        return 'female'
    elif 'male' in comparison_str:
        return 'male'
    else:
        return 'unknown'

# Apply function to create 'Gender' column
df_filtered3['Gender'] = df_filtered3['Comparison'].apply(get_gender)

# Split data into two separate dataframes
df_filtered3_male = df_filtered3[df_filtered3['Gender'] == 'male']
df_filtered3_female = df_filtered3[df_filtered3['Gender'] == 'female']

# Now, we can perform the mean calculation for each dataframe
df_grouped_filtered3_male = df_filtered3_male.groupby(['hgnc_symbol', 'Comparison'])['logFC'].mean().reset_index()
df_grouped_filtered3_male = df_grouped_filtered3_male.groupby('hgnc_symbol')['logFC'].mean().sort_values(ascending=False)
df_grouped_filtered3_male = df_grouped_filtered3_male.reset_index()

df_grouped_filtered3_female = df_filtered3_female.groupby(['hgnc_symbol', 'Comparison'])['logFC'].mean().reset_index()
df_grouped_filtered3_female = df_grouped_filtered3_female.groupby('hgnc_symbol')['logFC'].mean().sort_values(ascending=False)
df_grouped_filtered3_female = df_grouped_filtered3_female.reset_index()

# %%
# First group by 'hgnc_symbol' and 'Comparison', then calculate mean values for selected columns
df_grouped_filtered3_male = df_filtered3_male.groupby(['hgnc_symbol', 'Comparison']).agg({'logFC': 'mean', 'adj.P.Val': 'mean', 'gene_length': 'mean', 'score': 'mean'}).reset_index()
# Calculate the mean again for the logFC, adj.P.Val, gene_length and score
df_grouped_filtered3_male = df_grouped_filtered3_male.groupby('hgnc_symbol').agg({'logFC': 'mean', 'adj.P.Val': 'mean', 'gene_length': 'mean', 'score': 'mean'}).sort_values(by='logFC', ascending=False).reset_index()

# Do the same for the female dataset
df_grouped_filtered3_female = df_filtered3_female.groupby(['hgnc_symbol', 'Comparison']).agg({'logFC': 'mean', 'adj.P.Val': 'mean', 'gene_length': 'mean', 'score': 'mean'}).reset_index()
df_grouped_filtered3_female = df_grouped_filtered3_female.groupby('hgnc_symbol').agg({'logFC': 'mean', 'adj.P.Val': 'mean', 'gene_length': 'mean', 'score': 'mean'}).sort_values(by='logFC', ascending=False).reset_index()

# %%
df_grouped_filtered3_male.head(15)
# Out:
#    hgnc_symbol     logFC  adj.P.Val  gene_length     score
# 0        CD163  0.281479   0.004705      33081.0  3.450172
# 1        FCGBP  0.279457   0.005932      71304.0  4.015799
# 2         RGS1  0.272774   0.000539       4262.0  4.293200
# 3          LTF  0.270640   0.018173      49590.0  2.795102
# 4       MS4A6A  0.267749   0.000242      12653.0  6.313596
# 5     SERPINA5  0.267392   0.012084      31677.0  5.705393
# 6         SCIN  0.250890   0.001520      89606.0  5.284949
# 7          C4B  0.225471   0.001148      20624.0  5.572868
# 8        MS4A7  0.223040   0.000141      17467.0  7.592663
# 9           CP  0.214413   0.001038      59420.0  3.697166
# 10      CLEC5A  0.212925   0.004348      19651.0  3.668957
# 11   LINC01736  0.210666   0.003039       4824.0  4.277514
# 12       VSIG4  0.209842   0.005776      18388.0  3.409059
# 13        MSR1  0.207887   0.003533     459613.0  4.344736
# 14   LINC01094  0.207297   0.000275      44406.0  6.319205

# %%
df_grouped_filtered3_male.tail(15)
# Out:
#    hgnc_symbol     logFC     adj.P.Val  gene_length     score
# 46   LINC01007 -0.169460  7.000083e-03       6228.0 -3.996410
# 47   LINC02427 -0.171787  6.981372e-03      34356.0 -2.642314
# 48  AC117453.1 -0.173778  3.112618e-03     221472.0 -3.854482
# 49       PPEF1 -0.186631  6.492739e-05     152013.0 -6.267251
# 50  AC034268.2 -0.187496  8.034555e-05    1088875.0 -6.114241
# 51         VIP -0.191532  4.144106e-04       8969.0 -5.313054
# 52   SPRY4-AS1 -0.206272  1.687170e-05     346709.0 -8.742676
# 53  AC007424.1 -0.210312  1.012801e-05      48448.0 -7.788069
# 54        KRT5 -0.218126  1.029003e-03       5956.0 -6.094602
# 55    Z74021.1 -0.220478  1.584477e-02        407.0 -2.373739
# 56  AC011379.2 -0.250368  1.656191e-03      15733.0 -3.997734
# 57       KLRC2 -0.261844  1.282348e-03      15447.0 -5.273577
# 58        XIST -0.265365  1.576855e-02      32075.0 -3.931399
# 59   LINC01844 -0.273393  7.010560e-07      44807.0 -8.848798
# 60         CRH -0.313680  5.135485e-05       2089.0 -6.966726

# %%
df_grouped_filtered3_female.head(15)
# Out:
#    hgnc_symbol     logFC  adj.P.Val  gene_length     score
# 0          LTF  0.437603   0.015138      49590.0  5.057147
# 1        CD163  0.361311   0.006329      33081.0  4.014901
# 2         RGS1  0.343651   0.007917       4262.0  3.953615
# 3         XIST  0.343387   0.000147      32075.0  5.959030
# 4       MS4A6A  0.330639   0.000126      12653.0  6.692693
# 5    LINC01736  0.321607   0.000365       4824.0  7.021943
# 6           CP  0.313854   0.005391      59420.0  4.624681
# 7     SERPINA5  0.304612   0.013051      31677.0  5.153755
# 8          C4B  0.300093   0.001046      20624.0  7.346519
# 9         CD44  0.298049   0.006873      93533.0  5.302569
# 10        SCIN  0.295538   0.001177      89606.0  4.759582
# 11        PCK1  0.292492   0.003668       7042.0  3.609394
# 12      CLEC4E  0.285087   0.004468       7659.0  4.651783
# 13   LINC01094  0.283278   0.000088      44406.0  8.896984
# 14    HLA-DQA2  0.275038   0.010059       5874.0  3.369331

# %%
df_grouped_filtered3_female.tail(15)
# Out:
#    hgnc_symbol     logFC  adj.P.Val  gene_length      score
# 45      RNASE6  0.214256   0.001674       1200.0   4.648793
# 46  AC007424.1 -0.200047   0.000505      48448.0  -5.189802
# 47       KLRC2 -0.200380   0.018647      15447.0  -2.211933
# 48        KRT5 -0.204180   0.002562       5956.0  -3.387023
# 49   LINC02427 -0.205608   0.008848      34356.0  -2.529981
# 50     SLC28A2 -0.222499   0.004088      25613.0  -3.176168
# 51   SPRY4-AS1 -0.227323   0.000013     346709.0  -7.172480
# 52  AC034268.2 -0.235264   0.000051    1088875.0  -7.272496
# 53  AC051619.5 -0.238884   0.005957      43322.0  -2.887736
# 54       PPEF1 -0.251172   0.000009     152013.0  -8.335688
# 55         VIP -0.257950   0.000602       8969.0  -7.118755
# 56   LINC01844 -0.285124   0.000008      44807.0  -7.017684
# 57   LINC01007 -0.310879   0.000288       6228.0  -9.099435
# 58  AC117453.1 -0.336274   0.000031     221472.0 -11.323593
# 59         CRH -0.349579   0.000085       2089.0  -6.287904

# %%
df_grouped_filtered3_female.to_csv('filtered_female_MSBB.csv')
df_grouped_filtered3_male.to_csv('filtered_male_MSBB.csv')

# %%
# Filter for genes on X chromosome
df_filtered3_male_X = df_filtered3_male[df_filtered3_male['chromosome_name'] == 'X']
df_filtered3_female_X = df_filtered3_female[df_filtered3_female['chromosome_name'] == 'X']

# Then apply the rest of your analysis on these filtered dataframes
df_grouped_filtered3_male_X = df_filtered3_male_X.groupby(['hgnc_symbol', 'Comparison']).agg({'logFC': 'mean', 'adj.P.Val': 'mean', 'gene_length': 'mean', 'score': 'mean'}).reset_index()
df_grouped_filtered3_male_X = df_grouped_filtered3_male_X.groupby('hgnc_symbol').agg({'logFC': 'mean', 'adj.P.Val': 'mean', 'gene_length': 'mean', 'score': 'mean'}).sort_values(by='logFC', ascending=False).reset_index()

df_grouped_filtered3_female_X = df_filtered3_female_X.groupby(['hgnc_symbol', 'Comparison']).agg({'logFC': 'mean', 'adj.P.Val': 'mean', 'gene_length': 'mean', 'score': 'mean'}).reset_index()
df_grouped_filtered3_female_X = df_grouped_filtered3_female_X.groupby('hgnc_symbol').agg({'logFC': 'mean', 'adj.P.Val': 'mean', 'gene_length': 'mean', 'score': 'mean'}).sort_values(by='logFC', ascending=False).reset_index()

df_grouped_filtered3_female_X.head(15)
# Out:
#   hgnc_symbol     logFC  adj.P.Val  gene_length     score
# 0        XIST  0.343387   0.000147      32075.0  5.959030
# 1       VSIG4  0.266757   0.004191      18388.0  3.696120
# 2       PPEF1 -0.251172   0.000009     152013.0 -8.335688

# %%
df_grouped_filtered3_female_X.tail(15)
# Out:
#   hgnc_symbol     logFC  adj.P.Val  gene_length     score
# 0        XIST  0.343387   0.000147      32075.0  5.959030
# 1       VSIG4  0.266757   0.004191      18388.0  3.696120
# 2       PPEF1 -0.251172   0.000009     152013.0 -8.335688

# %% [markdown]
# # Checking individual genes

# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.contains('DDX3Y')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='logFC', ascending=False)

# Display the first 20 rows
df_filtered.head(20)
# Out:
#                                                                                          Comparison  \
# 159178      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 90971         diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP
# 136906      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 114297      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
# 22756   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 45595   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 68219   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 2         diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP
#
#         ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
# 159178  ENSG00000067048  0.236071  0.142151  0.329990  1.419404  4.940185
# 90971   ENSG00000067048  0.191080  0.107264  0.274896  1.419404  4.480706
# 136906  ENSG00000067048  0.138391  0.063201  0.213581  1.419404  3.617448
# 114297  ENSG00000067048  0.111602  0.037834  0.185370  1.419404  2.973454
# 22756   ENSG00000067048 -0.293602 -0.413881 -0.173322  1.419404 -4.797592
# 45595   ENSG00000067048 -0.295307 -0.432634 -0.157979  1.419404 -4.226408
# 68219   ENSG00000067048 -0.334063 -0.463448 -0.204678  1.419404 -5.074597
# 2       ENSG00000067048 -0.363231 -0.481393 -0.245068  1.419404 -6.041708
#
#              P.Value  adj.P.Val Direction hgnc_symbol  \
# 159178  1.339366e-06   0.000302      none       DDX3Y
# 90971   1.093057e-05   0.001402      none       DDX3Y
# 136906  3.548232e-04   0.003032      none       DDX3Y
# 114297  3.210174e-03   0.028873      none       DDX3Y
# 22756   2.063953e-06   0.000271      down       DDX3Y
# 45595   2.849925e-05   0.000208      down       DDX3Y
# 68219   5.385524e-07   0.000092      down       DDX3Y
# 2       2.918153e-09   0.000006      down       DDX3Y
#
#         percentage_gene_gc_content    gene_biotype chromosome_name  \
# 159178                   37.700812  protein_coding               Y
# 90971                    37.700812  protein_coding               Y
# 136906                   37.700812  protein_coding               Y
# 114297                   37.700812  protein_coding               Y
# 22756                    37.700812  protein_coding               Y
# 45595                    37.700812  protein_coding               Y
# 68219                    37.700812  protein_coding               Y
# 2                        37.700812  protein_coding               Y
#
#         gene_length     score
# 159178        16371  4.458146
# 90971         16371  3.454018
# 136906        16371  2.892034
# 114297        16371  1.721280
# 22756         16371 -4.783744
# 45595         16371 -4.947101
# 68219         16371 -5.636677
# 2             16371 -7.509982

# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.contains('SLC35D3')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='logFC', ascending=False)

# Display the first 20 rows
df_filtered.head(20)
# Out:
# Empty DataFrame
# Columns: [Comparison, ensembl_gene_id, logFC, CI.L, CI.R, AveExpr, t, P.Value, adj.P.Val, Direction, hgnc_symbol, percentage_gene_gc_content, gene_biotype, chromosome_name, gene_length, score]
# Index: []

# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.contains('MT1H')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='logFC', ascending=False)

# Display the first 20 rows
df_filtered.head(20)
# Out:
#                                                                                          Comparison  \
# 46080   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 136743      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 215       diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP
# 23236   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 113952      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
# 69058   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 165123      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 97335         diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP
#
#         ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
# 46080   ENSG00000205358  0.203269  0.029240  0.377297  0.809416  2.280611
# 136743  ENSG00000205358  0.153331  0.032742  0.273921  0.809416  2.482688
# 215     ENSG00000205358  0.148427  0.001882  0.294972  0.809416  1.977619
# 23236   ENSG00000205358  0.140719 -0.003691  0.285129  0.809416  1.902635
# 113952  ENSG00000205358  0.136801  0.024858  0.248744  0.809416  2.386129
# 69058   ENSG00000205358  0.121547 -0.040806  0.283901  0.809416  1.461787
# 165123  ENSG00000205358  0.052209 -0.093249  0.197666  0.809416  0.700820
# 97335   ENSG00000205358  0.042380 -0.084077  0.168837  0.809416  0.654369
#
#          P.Value  adj.P.Val Direction hgnc_symbol  percentage_gene_gc_content  \
# 46080   0.023199   0.054846      none        MT1H                   54.635258
# 136743  0.013403   0.045313      none        MT1H                   54.635258
# 215     0.048784   0.176168      none        MT1H                   54.635258
# 23236   0.057961   0.177385      none        MT1H                   54.635258
# 113952  0.017536   0.080366      none        MT1H                   54.635258
# 69058   0.144658   0.300689      none        MT1H                   54.635258
# 165123  0.483807   0.636491      none        MT1H                   54.635258
# 97335   0.513284   0.692834      none        MT1H                   54.635258
#
#           gene_biotype chromosome_name  gene_length     score
# 46080   protein_coding              16         1316  1.545055
# 136743  protein_coding              16         1316  1.566460
# 215     protein_coding              16         1316  0.874731
# 23236   protein_coding              16         1316  0.864571
# 113952  protein_coding              16         1316  1.255444
# 69058   protein_coding              16         1316  0.589332
# 165123  protein_coding              16         1316  0.206724
# 97335   protein_coding              16         1316  0.166270

# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.contains('CHRNA2')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='logFC', ascending=False)

# Display the first 20 rows
df_filtered.head(20)
# Out:
#                                                                                          Comparison  \
# 94849         diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP
# 161405      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 137779      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 875       diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP
# 48449   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 113995      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
# 68766   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 23079   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
#
#         ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
# 94849   ENSG00000120903 -0.059935 -0.112312 -0.007558  1.575024 -2.239520
# 161405  ENSG00000120903 -0.085178 -0.143617 -0.026740  1.575024 -2.852662
# 137779  ENSG00000120903 -0.100506 -0.155176 -0.045837  1.575024 -3.598044
# 875     ENSG00000120903 -0.105162 -0.165187 -0.045137  1.575024 -3.428834
# 48449   ENSG00000120903 -0.120289 -0.192581 -0.047997  1.575024 -3.256533
# 113995  ENSG00000120903 -0.132865 -0.183120 -0.082611  1.575024 -5.174306
# 68766   ENSG00000120903 -0.136817 -0.201985 -0.071650  1.575024 -4.108909
# 23079   ENSG00000120903 -0.155361 -0.217078 -0.093644  1.575024 -4.926713
#
#              P.Value  adj.P.Val Direction hgnc_symbol  \
# 94849   2.548194e-02   0.105684      none      CHRNA2
# 161405  4.485644e-03   0.034132      none      CHRNA2
# 137779  3.388661e-04   0.002923      none      CHRNA2
# 875     6.516462e-04   0.014801      none      CHRNA2
# 48449   1.196436e-03   0.004641      none      CHRNA2
# 113995  2.943942e-07   0.000108      none      CHRNA2
# 68766   4.597111e-05   0.001579      none      CHRNA2
# 23079   1.089613e-06   0.000176      none      CHRNA2
#
#         percentage_gene_gc_content    gene_biotype chromosome_name  \
# 94849                    50.760135  protein_coding               8
# 161405                   50.760135  protein_coding               8
# 137779                   50.760135  protein_coding               8
# 875                      50.760135  protein_coding               8
# 48449                    50.760135  protein_coding               8
# 113995                   50.760135  protein_coding               8
# 68766                    50.760135  protein_coding               8
# 23079                    50.760135  protein_coding               8
#
#         gene_length     score
# 94849         20128 -1.036277
# 161405        20128 -1.597261
# 137779        20128 -2.802128
# 875           20128 -2.032606
# 48449         20128 -2.631614
# 113995        20128 -4.530409
# 68766         20128 -3.212434
# 23079         20128 -4.386291

# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.contains('LTF')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='logFC', ascending=False)

# Display the first 20 rows
df_filtered.head(20)
# Out:
#                                                Comparison  ensembl_gene_id  \
# 45472   diagnosis_sex_tissue*age_death.AD_female_PHG -...  ENSG00000012223
# 22738   diagnosis_sex_tissue*age_death.AD_female_IFG -...  ENSG00000012223
# 136421  diagnosis_sex_tissue*age_death.AD_male_PHG - d...  ENSG00000012223
# 68224   diagnosis_sex_tissue*age_death.AD_female_STG -...  ENSG00000012223
# 113694  diagnosis_sex_tissue*age_death.AD_male_IFG - d...  ENSG00000012223
# 36      diagnosis_sex_tissue*age_death.AD_female_FP - ...  ENSG00000012223
# 159202  diagnosis_sex_tissue*age_death.AD_male_STG - d...  ENSG00000012223
# 91340   diagnosis_sex_tissue*age_death.AD_male_FP - di...  ENSG00000012223
# 135812  diagnosis_sex_tissue*age_death.AD_male_IFG - d...  ENSG00000228109
# 157567  diagnosis_sex_tissue*age_death.AD_male_PHG - d...  ENSG00000228109
# 106672  diagnosis_sex_tissue*age_death.AD_male_FP - di...  ENSG00000228109
# 152362  diagnosis_sex_tissue*age_death.AD_male_PHG - d...  ENSG00000071794
# 172337  diagnosis_sex_tissue*age_death.AD_male_STG - d...  ENSG00000228109
# 11039   diagnosis_sex_tissue*age_death.AD_female_FP - ...  ENSG00000071794
# 100961  diagnosis_sex_tissue*age_death.AD_male_FP - di...  ENSG00000071794
# 33879   diagnosis_sex_tissue*age_death.AD_female_IFG -...  ENSG00000071794
# 59665   diagnosis_sex_tissue*age_death.AD_female_PHG -...  ENSG00000228109
# 120657  diagnosis_sex_tissue*age_death.AD_male_IFG - d...  ENSG00000071794
# 167945  diagnosis_sex_tissue*age_death.AD_male_STG - d...  ENSG00000071794
# 120544  diagnosis_sex_tissue*age_death.AD_male_IFG - d...  ENSG00000163975
#
#            logFC      CI.L      CI.R   AveExpr         t       P.Value  \
# 45472   0.641804  0.406050  0.877559  1.070785  5.305905  2.048294e-07
# 22738   0.364281  0.165353  0.563208  1.070785  3.569099  4.081459e-04
# 68212                    39.781761       lncRNA               X        32075
# 10                       39.781761       lncRNA               X        32075
# 22753                    39.781761       lncRNA               X        32075
# 113756                   39.781761       lncRNA               X        32075
# 136524                   39.781761       lncRNA               X        32075
# 90954                    39.781761       lncRNA               X        32075
# 159153                   39.781761       lncRNA               X        32075
#
#            score
# 45495   7.849935
# 68212   6.161099
# 10      5.170472
# 22753   4.654611
# 113756 -1.634036
# 136524 -2.242376
# 90954  -2.772527
# 159153 -9.076657

# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.match('^CD163$')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='logFC', ascending=False)

# Display the first 20 rows
df_filtered.head(20)
# Out:
#                                                                                          Comparison  \
# 45474   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 68213   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 159155      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 22746   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 136423      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 14        diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP
# 90948         diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP
# 113691      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
#
#         ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
# 45474   ENSG00000177575  0.480617  0.282273  0.678961  4.136168  4.721901
# 68213   ENSG00000177575  0.354508  0.172908  0.536108  4.136168  3.804054
# 159155  ENSG00000177575  0.324283  0.165888  0.482678  4.136168  3.989509
# 22746   ENSG00000177575  0.314343  0.147521  0.481164  4.136168  3.671881
# 136423  ENSG00000177575  0.299185  0.169240  0.429131  4.136168  4.486589
# 14      ENSG00000177575  0.295776  0.128254  0.463299  4.136168  3.440545
# 90948   ENSG00000177575  0.263628  0.121131  0.406126  4.136168  3.605135
# 113691  ENSG00000177575  0.238819  0.111236  0.366402  4.136168  3.647643
#
#          P.Value  adj.P.Val Direction hgnc_symbol  percentage_gene_gc_content  \
# 45474   0.000003   0.000038        up       CD163                   37.423294
# 68213   0.000170   0.003583        up       CD163                   37.423294
# 159155  0.000081   0.003296        up       CD163                   37.423294
# 22746   0.000280   0.006831        up       CD163                   37.423294
# 136423  0.000010   0.000225        up       CD163                   37.423294
# 14      0.000655   0.014864        up       CD163                   37.423294
# 90948   0.000359   0.008464        up       CD163                   37.423294
# 113691  0.000305   0.006834      none       CD163                   37.423294
#
#           gene_biotype chromosome_name  gene_length     score
# 45474   protein_coding              12        33081  7.150894
# 68213   protein_coding              12        33081  3.486354
# 159155  protein_coding              12        33081  3.432747
# 22746   protein_coding              12        33081  2.965401
# 136423  protein_coding              12        33081  4.920958
# 14      protein_coding              12        33081  2.456956
# 90948   protein_coding              12        33081  2.697591
# 113691  protein_coding              12        33081  2.749391

# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.match('^CRH$')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='logFC', ascending=False)

# Display the first 20 rows
df_filtered.head(20)
# Out:
#                                                                                          Comparison  \
# 136424      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 90947         diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP
# 113682      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
# 11        diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP
# 22741   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 68217   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 159154      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 45488   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
#
#         ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
# 136424  ENSG00000147571 -0.281350 -0.384518 -0.178181  0.438421 -5.334387
# 90947   ENSG00000147571 -0.281565 -0.385120 -0.178010  0.438421 -5.318549
# 113682  ENSG00000147571 -0.304622 -0.399244 -0.210000  0.438421 -6.297314
# 11      ENSG00000147571 -0.317551 -0.438337 -0.196766  0.438421 -5.142627
# 22741   ENSG00000147571 -0.336733 -0.457436 -0.216031  0.438421 -5.457005
# 68217   ENSG00000147571 -0.339682 -0.472990 -0.206373  0.438421 -4.984242
# 159154  ENSG00000147571 -0.387183 -0.505196 -0.269170  0.438421 -6.417605
# 45488   ENSG00000147571 -0.404349 -0.552743 -0.255955  0.438421 -5.329984
#
#              P.Value  adj.P.Val Direction hgnc_symbol  \
# 136424  1.406078e-07   0.000010      down         CRH
# 90947   1.770210e-07   0.000192      down         CRH
# 113682  7.342294e-10   0.000002      down         CRH
# 11      4.388439e-07   0.000175      down         CRH
# 22741   8.733265e-08   0.000029      down         CRH
# 68217   9.346753e-07   0.000134      down         CRH
# 159154  3.717468e-10   0.000002      down         CRH
# 45488   1.612477e-07   0.000003      down         CRH
#
#         percentage_gene_gc_content    gene_biotype chromosome_name  \
#
#
#          P.Value  adj.P.Val Direction hgnc_symbol  percentage_gene_gc_content  \
# 45525   0.000030   0.000217        up        PCK1                    48.32434
# 68230   0.000148   0.003293        up        PCK1                    48.32434
# 22767   0.000118   0.003964        up        PCK1                    48.32434
# 24      0.000183   0.007196      none        PCK1                    48.32434
# 136759  0.009139   0.033911      none        PCK1                    48.32434
# 159669  0.051365   0.148996      none        PCK1                    48.32434
# 91681   0.086182   0.228666      none        PCK1                    48.32434
# 117593  0.317654   0.500393      none        PCK1                    48.32434
#
#           gene_biotype chromosome_name  gene_length     score
# 45525   protein_coding              20         7042  5.191810
# 68230   protein_coding              20         7042  3.315785
# 22767   protein_coding              20         7042  3.147041
# 24      protein_coding              20         7042  2.782939
# 136759  protein_coding              20         7042  1.710581
# 159669  protein_coding              20         7042  0.942428
# 91681   protein_coding              20         7042  0.710581
# 117593  protein_coding              20         7042  0.317597

# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.match('^AC099552.5$')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='logFC', ascending=False)

# Display the first 20 rows
df_filtered.head(20)
# Out:
# Empty DataFrame
# Columns: [Comparison, ensembl_gene_id, logFC, CI.L, CI.R, AveExpr, t, P.Value, adj.P.Val, Direction, hgnc_symbol, percentage_gene_gc_content, gene_biotype, chromosome_name, gene_length, score]
# Index: []

# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.match('^S100A4$')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='logFC', ascending=False)

# Display the first 20 rows
df_filtered.head(20)
# Out:
#                                                                                          Comparison  \
# 45533   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 136440      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 68291   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 22849   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 85        diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP
# 113781      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
# 159370      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 91192         diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP
#
#         ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
# 45533   ENSG00000196154  0.338443  0.207967  0.468919  1.031745  5.069102
# 136440  ENSG00000196154  0.242672  0.150455  0.334889  1.031745  5.142608
# 68291   ENSG00000196154  0.223382  0.103861  0.342903  1.031745  3.652418
# 22849   ENSG00000196154  0.206912  0.096743  0.317081  1.031745  3.670305
# 85      ENSG00000196154  0.190160  0.078719  0.301601  1.031745  3.334635
# 113781  ENSG00000196154  0.165231  0.078002  0.252460  1.031745  3.701736
# 159370  ENSG00000196154  0.161694  0.054391  0.268997  1.031745  2.944812
# 91192   ENSG00000196154  0.129095  0.032765  0.225425  1.031745  2.618914
#
#              P.Value  adj.P.Val Direction hgnc_symbol  \
# 45533   6.181864e-07   0.000010        up      S100A4
# 136440  3.766794e-07   0.000021      none      S100A4
# 68291   2.945500e-04   0.005001      none      S100A4
# 22849   2.744073e-04   0.006767      none      S100A4
# 85      9.303628e-04   0.017987      none      S100A4
# 113781  2.384946e-04   0.005837      none      S100A4
# 159370  3.398268e-03   0.029088      none      S100A4
# 91192   9.115840e-03   0.056155      none      S100A4
#
#         percentage_gene_gc_content    gene_biotype chromosome_name  \
# 45533                    56.299816  protein_coding               1
# 136440                   56.299816  protein_coding               1
# 68291                    56.299816  protein_coding               1
# 22849                    56.299816  protein_coding               1
# 85                       56.299816  protein_coding               1
# 113781                   56.299816  protein_coding               1
# 159370                   56.299816  protein_coding               1
# 91192                    56.299816  protein_coding               1
#
#         gene_length     score
# 45533          6524  7.032794
# 136440         6524  5.955077
# 68291          6524  2.876821
# 22849          6524  2.668361
# 85             6524  2.110527
# 113781         6524  2.635164
# 159370         6524  1.805908
# 91192          6524  1.422939

# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.match('^CYTL1$')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='logFC', ascending=False)

# Display the first 20 rows
df_filtered.head(20)
# Out:
#                                                                                          Comparison  \
# 45565   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 68238   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 22796   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 136454      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 159246      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 114       diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP
# 113806      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
# 91503         diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP
#
#         ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
# 45565   ENSG00000170891  0.313006  0.215912  0.410101  0.609439  6.317082
# 68238   ENSG00000170891  0.268048  0.176712  0.359383  0.609439  5.750848
# 22796   ENSG00000170891  0.239075  0.156209  0.321941  0.609439  5.653509
# 136454  ENSG00000170891  0.227623  0.155720  0.299527  0.609439  6.203343
# 159246  ENSG00000170891  0.192490  0.109248  0.275731  0.609439  4.531339
# 114     ENSG00000170891  0.178211  0.092785  0.263637  0.609439  4.087939
# 113806  ENSG00000170891  0.160443  0.093226  0.227661  0.609439  4.677351
# 91503   ENSG00000170891  0.110358  0.035498  0.185218  0.609439  2.888785
#
#              P.Value     adj.P.Val Direction hgnc_symbol  \
#
# 449                      42.593127       lncRNA               7        58925
# 159533                   42.593127       lncRNA               7        58925
# 23094                    42.593127       lncRNA               7        58925
# 68306                    42.593127       lncRNA               7        58925
# 45592                    42.593127       lncRNA               7        58925
#
#             score
# 93812   -1.173975
# 115914  -1.356333
# 137953  -2.685780
# 449     -2.340562
# 159533  -3.339590
# 23094   -3.691434
# 68306   -6.346611
# 45592  -13.033156

# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.match('^KRT5$')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='logFC', ascending=False)

# Display the first 20 rows
df_filtered.head(20)
# Out:
#                                                                                          Comparison  \
# 383       diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP
# 91032         diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP
# 68391   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 22844   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 136489      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 159204      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 45925   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 113684      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
#
#         ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
# 383     ENSG00000186081 -0.128191 -0.219345 -0.037037 -0.424516 -2.757053
# 91032   ENSG00000186081 -0.161779 -0.240994 -0.082563 -0.424516 -4.003795
# 68391   ENSG00000186081 -0.183422 -0.283643 -0.083200 -0.424516 -3.587985
# 22844   ENSG00000186081 -0.209032 -0.301582 -0.116483 -0.424516 -4.427937
# 136489  ENSG00000186081 -0.210642 -0.294005 -0.127280 -0.424516 -4.953800
# 159204  ENSG00000186081 -0.212933 -0.301623 -0.124242 -0.424516 -4.706825
# 45925   ENSG00000186081 -0.220086 -0.335597 -0.104575 -0.424516 -3.735362
# 113684  ENSG00000186081 -0.287152 -0.360862 -0.213441 -0.424516 -7.637378
#
#              P.Value     adj.P.Val Direction hgnc_symbol  \
# 383     6.064300e-03  5.232559e-02      none        KRT5
# 91032   7.166440e-05  3.575196e-03      none        KRT5
# 68391   3.683970e-04  5.740058e-03      none        KRT5
# 22844   1.177532e-05  8.831175e-04      none        KRT5
# 136489  8.923837e-07  3.962741e-05      none        KRT5
# 159204  3.246003e-06  5.011869e-04      none        KRT5
# 45925   2.066255e-04  1.064304e-03      none        KRT5
# 113684  8.931531e-14  1.015336e-09      down        KRT5
#
#         percentage_gene_gc_content    gene_biotype chromosome_name  \
# 383                       50.80591  protein_coding              12
# 91032                     50.80591  protein_coding              12
# 68391                     50.80591  protein_coding              12
# 22844                     50.80591  protein_coding              12
# 136489                    50.80591  protein_coding              12
# 159204                    50.80591  protein_coding              12
# 45925                     50.80591  protein_coding              12
# 113684                    50.80591  protein_coding              12
#
#         gene_length      score
# 383            5956  -1.456528
# 91032          5956  -2.876340
# 68391          5956  -2.692260
# 22844          5956  -3.763986
# 136489         5956  -5.434145
# 159204         5956  -4.083095
# 45925          5956  -3.704824
# 113684         5956 -11.984828

# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.match('^VGF$')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='logFC', ascending=False)

# Display the first 20 rows
df_filtered.head(20)
# Out:
#                                                                                          Comparison  \
# 136761      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 113840      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
# 22927   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 90974         diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP
# 159256      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 33        diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP
# 68246   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 45625   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
#
#         ensembl_gene_id     logFC      CI.L      CI.R  AveExpr         t  \
# 136761  ENSG00000128564 -0.151733 -0.242629 -0.060836  4.05574 -3.253273
# 113840  ENSG00000128564 -0.153018 -0.240445 -0.065591  4.05574 -3.411031
# 22927   ENSG00000128564 -0.180145 -0.292094 -0.068197  4.05574 -3.136128
# 90974   ENSG00000128564 -0.186017 -0.282415 -0.089618  4.05574 -3.760693
# 159256  ENSG00000128564 -0.188371 -0.295270 -0.081473  4.05574 -3.434245
# 33      ENSG00000128564 -0.231889 -0.344172 -0.119606  4.05574 -4.024890
# 68246   ENSG00000128564 -0.260759 -0.382366 -0.139152  4.05574 -4.178956
# 45625   ENSG00000128564 -0.281866 -0.414705 -0.149026  4.05574 -4.135259
#
#          P.Value  adj.P.Val Direction hgnc_symbol  percentage_gene_gc_content  \
#
# 93301   ENSG00000166523  0.075440 -0.026960  0.177840  0.326074  1.443453
# 118429  ENSG00000166523  0.048999 -0.043032  0.141030  0.326074  1.043170
#
#              P.Value  adj.P.Val Direction hgnc_symbol  \
# 45502   1.205831e-07   0.000003        up      CLEC4E
# 68227   6.933654e-06   0.000461        up      CLEC4E
# 22775   1.922498e-05   0.001207      none      CLEC4E
# 63      7.789698e-04   0.016201      none      CLEC4E
# 159307  2.844479e-03   0.026096      none      CLEC4E
# 136796  2.582149e-03   0.012957      none      CLEC4E
# 93301   1.496274e-01   0.322764      none      CLEC4E
# 118429  2.974224e-01   0.478604      none      CLEC4E
#
#         percentage_gene_gc_content    gene_biotype chromosome_name  \
# 45502                    39.783262  protein_coding              12
# 68227                    39.783262  protein_coding              12
# 22775                    39.783262  protein_coding              12
# 63                       39.783262  protein_coding              12
# 159307                   39.783262  protein_coding              12
# 136796                   39.783262  protein_coding              12
# 93301                    39.783262  protein_coding              12
# 118429                   39.783262  protein_coding              12
#
#         gene_length     score
# 45502          7659  8.144513
# 68227          7659  4.485302
# 22775          7659  3.782220
# 63             7659  2.195098
# 159307         7659  1.882881
# 136796         7659  2.188727
# 93301          7659  0.529599
# 118429         7659  0.336095

# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.match('^SLPI$')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='logFC', ascending=False)

# Display the first 20 rows
df_filtered.head(20)
# Out:
#                                                                                          Comparison  \
# 45568   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 26        diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP
# 91000         diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP
# 23300   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 137532      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 72001   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 122812      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
# 160871      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
#
#         ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
# 45568   ENSG00000124107  0.311554  0.118719  0.504389  0.102447  3.151866
# 26      ENSG00000124107  0.246891  0.094393  0.399388  0.102447  3.158350
# 91000   ENSG00000124107  0.169204  0.032982  0.305425  0.102447  2.423166
# 23300   ENSG00000124107  0.135020 -0.023398  0.293437  0.102447  1.662700
# 137532  ENSG00000124107  0.107630 -0.051465  0.266725  0.102447  1.319760
# 72001   ENSG00000124107  0.068285 -0.121665  0.258235  0.102447  0.701307
# 122812  ENSG00000124107  0.029588 -0.108686  0.167862  0.102447  0.417442
# 160871  ENSG00000124107 -0.093189 -0.269536  0.083158  0.102447 -1.030896
#
#          P.Value  adj.P.Val Direction hgnc_symbol  percentage_gene_gc_content  \
# 45568   0.001707   0.006239        up        SLPI                   51.289768
# 26      0.001689   0.025042      none        SLPI                   51.289768
# 91000   0.015696   0.078172      none        SLPI                   51.289768
# 23300   0.096949   0.244380      none        SLPI                   51.289768
# 137532  0.187209   0.323680      none        SLPI                   51.289768
# 72001   0.483336   0.652367      none        SLPI                   51.289768
# 122812  0.676463   0.802196      none        SLPI                   51.289768
# 160871  0.302883   0.470603      none        SLPI                   51.289768
#
#           gene_biotype chromosome_name  gene_length     score
# 45568   protein_coding              20         2326  3.010904
# 26      protein_coding              20         2326  2.049765
# 91000   protein_coding              20         2326  1.311027
# 23300   protein_coding              20         2326  0.700396
# 137532  protein_coding              20         2326  0.545552
# 72001   protein_coding              20         2326  0.198618
# 122812  protein_coding              20         2326  0.098594
# 160871  protein_coding              20         2326 -0.359316

# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.match('^SLC32A1$')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='logFC', ascending=False)

# Display the first 20 rows
df_filtered.head(20)
# Out:
#                                                                                          Comparison  \
# 102478        diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP
# 20816     diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP
# 36068   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 122312      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
# 165174      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 141183      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 71679   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 49222   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
#
#         ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
#
#
#              P.Value     adj.P.Val Direction hgnc_symbol  \
# 46118   3.484410e-10  3.130622e-08      none        TJP2
# 70243   2.243301e-03  1.923216e-02      none        TJP2
# 141026  8.674476e-03  3.259344e-02      none        TJP2
# 29106   7.918997e-02  2.149482e-01      none        TJP2
# 169519  2.308329e-01  3.929198e-01      none        TJP2
# 124988  3.136130e-01  4.962283e-01      none        TJP2
# 13202   4.614324e-01  6.583700e-01      none        TJP2
# 110432  8.197239e-01  9.058774e-01      none        TJP2
#
#         percentage_gene_gc_content    gene_biotype chromosome_name  \
# 46118                    43.413845  protein_coding               9
# 70243                    43.413845  protein_coding               9
# 141026                   43.413845  protein_coding               9
# 29106                    43.413845  protein_coding               9
# 169519                   43.413845  protein_coding               9
# 124988                   43.413845  protein_coding               9
# 13202                    43.413845  protein_coding               9
# 110432                   43.413845  protein_coding               9
#
#         gene_length     score
# 46118        153352  9.170774
# 70243        153352  1.878654
# 141026       153352  1.576815
# 29106        153352  0.701664
# 169519       153352  0.418696
# 124988       153352  0.311452
# 13202        153352  0.185221
# 110432       153352 -0.043165

# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.match('^VLDLR$')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='logFC', ascending=False)

# Display the first 20 rows
df_filtered.head(20)
# Out:
#                                                                                          Comparison  \
# 125491      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
# 100473        diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP
# 145181      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 27731   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 164156      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 3638      diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP
# 70819   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 50759   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
#
#         ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
# 125491  ENSG00000147852 -0.021953 -0.051276  0.007370  4.492784 -1.469549
# 100473  ENSG00000147852 -0.028380 -0.059486  0.002725  4.492784 -1.790983
# 145181  ENSG00000147852 -0.036278 -0.065930 -0.006626  4.492784 -2.401552
# 27731   ENSG00000147852 -0.058234 -0.094999 -0.021469  4.492784 -3.109220
# 164156  ENSG00000147852 -0.058505 -0.093384 -0.023626  4.492784 -3.292528
# 3638    ENSG00000147852 -0.064523 -0.100614 -0.028432  4.492784 -3.509345
# 70819   ENSG00000147852 -0.081092 -0.120348 -0.041836  4.492784 -4.054858
# 50759   ENSG00000147852 -0.087242 -0.129503 -0.044981  4.492784 -4.052172
#
#          P.Value  adj.P.Val Direction hgnc_symbol  percentage_gene_gc_content  \
# 125491  0.142326   0.298957      none       VLDLR                    42.01202
# 100473  0.074069   0.207923      none       VLDLR                    42.01202
# 145181  0.016709   0.053398      none       VLDLR                    42.01202
# 27731   0.002012   0.022767      none       VLDLR                    42.01202
# 164156  0.001082   0.015320      none       VLDLR                    42.01202
# 3638    0.000506   0.012714      none       VLDLR                    42.01202
# 70819   0.000061   0.001882      none       VLDLR                    42.01202
# 50759   0.000063   0.000399      none       VLDLR                    42.01202
#
#           gene_biotype chromosome_name  gene_length     score
# 125491  protein_coding               9        38270 -0.536030
# 100473  protein_coding               9        38270 -0.701734
# 145181  protein_coding               9        38270 -1.319482
# 27731   protein_coding               9        38270 -1.741199
# 164156  protein_coding               9        38270 -1.924065
# 3638    protein_coding               9        38270 -2.022081
# 70819   protein_coding               9        38270 -2.955471
# 50759   protein_coding               9        38270 -3.708440

# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.match('^PCK1$')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='logFC', ascending=False)

# Display the first 20 rows
df_filtered.head(20)
# Out:
#                                                                                          Comparison  \
# 45525   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 68230   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 22767   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
# 24        diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP
# 136759      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 159669      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 91681         diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP
# 117593      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.match('^HNF4A$')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='logFC', ascending=False)

# Display the first 20 rows
df_filtered.head(20)
# Out:
#                                                                                          Comparison  \
# 8057      diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP
# 111812        diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP
# 167497      diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG
# 75832   diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG
# 142410      diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG
# 53544   diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG
# 116061      diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG
# 25341   diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG
#
#         ensembl_gene_id     logFC      CI.L      CI.R   AveExpr         t  \
# 8057    ENSG00000101076  0.037494 -0.025604  0.100592  0.074724  1.165802
# 111812  ENSG00000101076  0.003031 -0.052061  0.058123  0.074724  0.107935
# 167497  ENSG00000101076 -0.039668 -0.105062  0.025726  0.074724 -1.190094
# 75832   ENSG00000101076 -0.045084 -0.117112  0.026945  0.074724 -1.227990
# 142410  ENSG00000101076 -0.049616 -0.110887  0.011656  0.074724 -1.588689
# 53544   ENSG00000101076 -0.062802 -0.142625  0.017021  0.074724 -1.543577
# 116061  ENSG00000101076 -0.068863 -0.125035 -0.012692  0.074724 -2.405207
# 25341   ENSG00000101076 -0.080533 -0.148696 -0.012370  0.074724 -2.317956
#
#          P.Value  adj.P.Val Direction hgnc_symbol  percentage_gene_gc_content  \
# 8057    0.244201   0.451719      none       HNF4A                   48.209691
# 111812  0.914082   0.957210      none       HNF4A                   48.209691
# 167497  0.234401   0.397031      none       HNF4A                   48.209691
# 75832   0.219911   0.395665      none       HNF4A                   48.209691
# 142410  0.112456   0.223223      none       HNF4A                   48.209691
# 53544   0.123179   0.211749      none       HNF4A                   48.209691
# 116061  0.016372   0.077081      none       HNF4A                   48.209691
# 25341   0.020747   0.095370      none       HNF4A                   48.209691
#
#           gene_biotype chromosome_name  gene_length     score
# 8057    protein_coding              20        78897  0.358318
# 111812  protein_coding              20        78897  0.019050
# 167497  protein_coding              20        78897 -0.417409
# 75832   protein_coding              20        78897 -0.421241
# 142410  protein_coding              20        78897 -0.684389
# 53544   protein_coding              20        78897 -0.717876
# 116061  protein_coding              20        78897 -1.192403
# 25341   protein_coding              20        78897 -1.106181

# %%
# Create a boolean mask
mask = df['hgnc_symbol'].str.match('^LAMP2$')

# Apply the mask to the dataframe and sort
df_filtered = df[mask].sort_values(by='logFC', ascending=False)

# Display the first 20 rows
df_filtered.head(20)
# Out:
#                                                Comparison  ensembl_gene_id  \
# 46161   diagnosis_sex_tissue*age_death.AD_female_PHG -...  ENSG00000005893
# 68893   diagnosis_sex_tissue*age_death.AD_female_STG -...  ENSG00000005893
# 137268  diagnosis_sex_tissue*age_death.AD_male_PHG - d...  ENSG00000005893
# 23761   diagnosis_sex_tissue*age_death.AD_female_IFG -...  ENSG00000005893
# 160717  diagnosis_sex_tissue*age_death.AD_male_STG - d...  ENSG00000005893
# 2231    diagnosis_sex_tissue*age_death.AD_female_FP - ...  ENSG00000005893
# 117105  diagnosis_sex_tissue*age_death.AD_male_IFG - d...  ENSG00000005893
# 96786   diagnosis_sex_tissue*age_death.AD_male_FP - di...  ENSG00000005893
#
#            logFC      CI.L      CI.R   AveExpr         t       P.Value  \
# 46161   0.197158  0.134284  0.260031  8.568006  6.123694  2.163124e-09
# 68893   0.128778  0.070369  0.187188  8.568006  4.305523  2.059601e-05
# 137268  0.117594  0.073200  0.161988  8.568006  5.172843  3.207196e-07
# 23761   0.113718  0.058773  0.168663  8.568006  4.041717  6.180604e-05
# 160717  0.096361  0.044350  0.148371  8.568006  3.618075  3.283862e-04
# 2231    0.079407  0.025105  0.133710  8.568006  2.855657  4.491036e-03
# 117105  0.058513  0.014561  0.102465  8.568006  2.599787  9.564198e-03
# 96786   0.045682 -0.001353  0.092718  8.568006  1.896670  5.845302e-02
#
#            adj.P.Val Direction hgnc_symbol  percentage_gene_gc_content  \
# 46161   1.170971e-07      none       LAMP2                   38.794867
# 68893   9.695050e-04      none       LAMP2                   38.794867
# 137268  1.855441e-05      none       LAMP2                   38.794867
# 23761   2.585499e-03      none       LAMP2                   38.794867
# 160717  7.458730e-03      none       LAMP2                   38.794867
# 2231    4.424459e-02      none       LAMP2                   38.794867
# 117105  5.617453e-02      none       LAMP2                   38.794867
# 96786   1.794717e-01      none       LAMP2                   38.794867
#
#           gene_biotype chromosome_name  gene_length
# 46161   protein_coding               X        41539
# 68893   protein_coding               X        41539
# 137268  protein_coding               X        41539
# 23761   protein_coding               X        41539
# 160717  protein_coding               X        41539
# 2231    protein_coding               X        41539
# 117105  protein_coding               X        41539
# 96786   protein_coding               X        41539

# %%
df['Direction'].value_counts()
# Out:
# none    181555
# up         185
# down       148
# Name: Direction, dtype: int64

# %% [markdown]
# # looking at proteins labeled up or down regulated

# %%
# Filter dataframe for rows where the direction is 'up'
df_upregulated = df[df['Direction'] == 'up']

# Filter dataframe for rows where the direction is 'down'
df_downregulated = df[df['Direction'] == 'down']

# %%
# Get the unique upregulated proteins
upregulated_proteins = df_upregulated['hgnc_symbol'].unique()

# Get the unique downregulated proteins
downregulated_proteins = df_downregulated['hgnc_symbol'].unique()

# %%
downregulated_proteins
# Out:
# array(['USP9Y', 'RPS4Y1', 'DDX3Y', 'UTY', 'TXLNGY', 'PCDH11Y', 'KDM5D',
#        'ZFY', 'TTTY14', 'CRH', 'ANOS2P', 'NLGN4Y', 'LINC01844',
#        'AC064829.1', 'PRKY', 'AC117453.1', 'SELE', 'TTR', 'LINC01007',
#        'FBN3', 'EIF1AY', 'AC015819.3', 'IGFN1', 'LINC01331', 'AP001993.1',
#        'LINC00390', 'LINC02055', 'NEUROD6', 'RGS4', 'AC112481.2', 'VIP',
#        'AC008780.1', 'LINC00507', 'PPEF1', 'C4orf54', 'LINC01202',
#        'AL583827.1', 'MCHR2', 'AC096570.1', 'NXPH2', 'HSPB3', 'LINC02263',
#        'WNT7B', 'CARTPT', 'OLFM3', 'CBLN4', 'CTXN3', 'AL157944.1',
#        'PART1', 'DLX6-AS1', 'FREM3', 'AL353709.1', 'GABRA1', 'AC034268.2',
#        'OTOGL', 'MAL2', 'WIF1', 'SPTSSB', 'AJ009632.2', 'VGF',
#        'AC025160.1', 'KCNV1', 'GAP43', 'PCSK1', 'AC037441.1', 'MTCO1P12',
#        'SST', 'AC021733.3', 'RXFP1', 'GLRA3', 'CALB1', 'SNX10', 'ABCC12',
#        'LINC02217', 'TTTY10', 'ANKRD18DP', 'OR2M3', 'HAPLN1', 'TAC1',
#        'SERTM1', 'RN7SL314P', 'KLRC2', 'ADAMTS18', 'AC011379.2', 'KRT5',
#        'SNORD3A', 'XIST'], dtype=object)

# %%
upregulated_proteins
# Out:
# array(['XIST', 'RGS1', 'CD163', 'MS4A6A', 'SCIN', 'LTF', 'LINC01736',
#        'PCK1', 'CHI3L2', 'SERPINA5', 'C4B', 'CD44', 'LINC01094', 'CP',
#        'APLNR', 'LINC01088', 'OR7A5', 'AL390755.1', 'C4A', 'PIRT',
#        'C10orf105', 'ALOX15B', 'AC100801.1', 'C1orf87', 'CLEC4E',
#        'RASSF9', 'HLA-DQA2', 'FPR3', 'GMPR', 'LINC01291', 'MS4A7',
#        'CLEC7A', 'GMNC', 'HLA-DRB6', 'AL929091.1', 'MSR1', 'CAPS',
#        'GALNT15', 'ADORA3', 'AL031056.1', 'FOXJ1', 'SIGLEC8', 'HLA-DRA',
#        'AL355974.2', 'HLA-DMB', 'S100A4', 'KLHL6', 'SLC14A1', 'VSIG4',
#        'LINC02432', 'HERC2P3', 'CXCR4', 'HLA-DOA', 'FAM177B', 'LINC01338',
#        'AL627316.1', 'HLA-DPA1', 'C3', 'FCGR2C', 'PLIN1', 'TNC',
#        'AC008571.2', 'FKBP5', 'C1QA', 'CD74', 'FCGR2A', 'STEAP3',
#        'SIRPB2', 'ITPKB', 'CYTL1', 'AQP1', 'SLC27A6', 'SLPI', 'SERPINA3',
#        'AZGP1', 'SLC11A1', 'HCLS1', 'PHYHD1', 'CYP4F12', 'SLC1A5',
#        'TXNIP', 'CLEC5A', 'C1QB', 'SPARC', 'MS4A4A', 'ITGB4', 'SLC7A2',
#        'LAIR1', 'LINC00836', 'CD86', 'AL355974.1', 'AL392172.2', 'FOS',
#        'IL13RA1', 'RNASE6', 'NEAT1', 'CHST6', 'PI16', 'ITGB2', 'SOCS3',
#        'EDA2R', 'C1QC', 'PDK4', 'AC073941.1', 'KIF19', 'GPIHBP1', 'WDR49',
#        'ID3', 'RASL12', 'LRP2', 'LINC01480', 'AC098679.5', 'LINC02251',
#        'LINC01470', 'C3AR1', 'HLA-DRB5', 'AC009063.2', 'SYTL4', 'IL10RA',
#        'CD34', 'SNX20', 'SPN', 'FCER1G', 'CCL2', 'AC188617.1', 'TMPRSS5',
#        'ANXA2', 'CDKN1C', 'TSPAN8', 'AHNAK', 'SLC16A12', 'ADH1B', 'IL18',
#        'TLR5', 'TLR2', 'SYK', 'C21orf62', 'CFAP47', 'TBXAS1', 'FCGR2B',
#        'FCGBP'], dtype=object)

# %%
df.columns
# Out:
# Index(['Comparison', 'ensembl_gene_id', 'logFC', 'CI.L', 'CI.R', 'AveExpr',
#        't', 'P.Value', 'adj.P.Val', 'Direction', 'hgnc_symbol',
#        'percentage_gene_gc_content', 'gene_biotype', 'chromosome_name',
#        'gene_length', 'score'],
#       dtype='object')

# %% [markdown]
# # modeling

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['Comparison', 'ensembl_gene_id', 'logFC', 'CI.L', 'CI.R', 'AveExpr',
#        't', 'P.Value', 'adj.P.Val', 'Direction', 'hgnc_symbol',
#        'percentage_gene_gc_content', 'gene_biotype', 'chromosome_name',
#        'gene_length', 'score'],
#       dtype='object')

# %%
df['Comparison'].value_counts()
# Out:
# diagnosis_sex_tissue*age_death.AD_female_FP - diagnosis_sex_tissue*age_death.CT_female_FP      22736
# diagnosis_sex_tissue*age_death.AD_female_IFG - diagnosis_sex_tissue*age_death.CT_female_IFG    22736
# diagnosis_sex_tissue*age_death.AD_female_PHG - diagnosis_sex_tissue*age_death.CT_female_PHG    22736
# diagnosis_sex_tissue*age_death.AD_female_STG - diagnosis_sex_tissue*age_death.CT_female_STG    22736
# diagnosis_sex_tissue*age_death.AD_male_FP - diagnosis_sex_tissue*age_death.CT_male_FP          22736
# diagnosis_sex_tissue*age_death.AD_male_IFG - diagnosis_sex_tissue*age_death.CT_male_IFG        22736
# diagnosis_sex_tissue*age_death.AD_male_PHG - diagnosis_sex_tissue*age_death.CT_male_PHG        22736
# diagnosis_sex_tissue*age_death.AD_male_STG - diagnosis_sex_tissue*age_death.CT_male_STG        22736
# Name: Comparison, dtype: int64

# %%
df_pivot = df.pivot(index='Comparison', columns='ensembl_gene_id', values='logFC')

# %%
# Standardize the data
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_pivot)

# Apply PCA
pca = PCA(n_components=2)  # for 2D PCA
principalComponents = pca.fit_transform(df_scaled)

# %%
# Fit the PCA model
pca = PCA()
pca.fit(df_scaled)

# Examine the explained variance ratios
explained_variance = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance)

# %%
plt.figure(figsize=(8, 6))
plt.plot(cumulative_variance)
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.show()

# %%
df_pivot = df.pivot(index='Comparison', columns='ensembl_gene_id', values='logFC')

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(df_scaled)


df_pca = pd.DataFrame(data = principalComponents, columns = ['PC1', 'PC2'])


df_pca.index = df_pivot.index


plt.figure(figsize=(8, 6))
plt.scatter(df_pca['PC1'], df_pca['PC2'])
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')

# labels
for i, comparison in enumerate(df_pca.index):
    plt.annotate(comparison, (df_pca.iloc[i].PC1, df_pca.iloc[i].PC2))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 pca = PCA(n_components=2)
#       2 principalComponents = pca.fit_transform(df_scaled)
#       5 df_pca = pd.DataFrame(data = principalComponents, columns = ['PC1', 'PC2'])
#
# NameError: name 'PCA' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set the style
plt.style.use('seaborn-darkgrid')

# Set the plot size
fig, ax = plt.subplots(figsize=(12, 8))

# Calculate CDF
data_sorted = np.sort(df['logFC'])
p = 1. * np.arange(len(df)) / (len(df) - 1)

# Plot CDF
ax.plot(data_sorted, p, color='skyblue')

# Get the logFC values for SERPINA5 and APOE
serpina5_logFCs = df.loc[df['hgnc_symbol'] == 'SERPINA5', 'logFC']
apoe_logFCs = df.loc[df['hgnc_symbol'] == 'APOE', 'logFC']

# Highlight SERPINA5's positions
for logFC in serpina5_logFCs:
    ax.axvline(logFC, color='red', linestyle='--')

# Highlight APOE's positions
for logFC in apoe_logFCs:
    ax.axvline(logFC, color='blue', linestyle='--')

# Set the title and labels
ax.set_title('CDF of logFC values with SERPINA5 and APOE highlighted (MSBB)', fontsize=16)
ax.set_xlabel('logFC', fontsize=14)
ax.set_ylabel('CDF', fontsize=14)

# Create a custom legend
from matplotlib.lines import Line2D
custom_lines = [Line2D([0], [0], color='red', lw=2),
                Line2D([0], [0], color='blue', lw=2)]
ax.legend(custom_lines, ['SERPINA5', 'APOE'], fontsize=12)

# Display the plot
plt.show()
# Out:
# /var/folders/38/8tgmhx7s5t3_6pmj8rgrysmm0000gn/T/ipykernel_64746/853200982.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set the style
plt.style.use('seaborn-darkgrid')

# Set the plot size
fig, ax = plt.subplots(figsize=(12, 8))

# Calculate CDF
data_sorted = np.sort(df['logFC'])
p = 1. * np.arange(len(df)) / (len(df) - 1)

# Plot CDF
ax.plot(data_sorted, p, color='skyblue')

# Get the logFC values for SERPINA5 and APOE
serpina5_logFCs = df.loc[df['hgnc_symbol'] == 'S100A4', 'logFC']
apoe_logFCs = df.loc[df['hgnc_symbol'] == 'APOE', 'logFC']

# Highlight SERPINA5's positions
for logFC in serpina5_logFCs:
    ax.axvline(logFC, color='red', linestyle='--')

# Highlight APOE's positions
for logFC in apoe_logFCs:
    ax.axvline(logFC, color='blue', linestyle='--')

# Set the title and labels
ax.set_title('CDF of logFC values with S100A4 and APOE highlighted (MSBB)', fontsize=16)
ax.set_xlabel('logFC', fontsize=14)
ax.set_ylabel('CDF', fontsize=14)

# Create a custom legend
from matplotlib.lines import Line2D
custom_lines = [Line2D([0], [0], color='red', lw=2),
                Line2D([0], [0], color='blue', lw=2)]
ax.legend(custom_lines, ['S100A4', 'APOE'], fontsize=12)

# Display the plot
plt.show()
# Out:
# /var/folders/38/8tgmhx7s5t3_6pmj8rgrysmm0000gn/T/ipykernel_64746/1053193036.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Calculate CDF
data_sorted = np.sort(df['logFC'])
p = 1. * np.arange(len(df)) / (len(df) - 1)

# Plot CDF
plt.figure(figsize=(10, 6))  # Making the figure larger to accommodate labels
plt.plot(data_sorted, p)
plt.xlabel('logFC')
plt.ylabel('CDF')

# Get the rows for SERPINA5 and APOE
serpina5_rows = df.loc[df['hgnc_symbol'] == 'SERPINA5']
apoe_rows = df.loc[df['hgnc_symbol'] == 'APOE']

# Highlight SERPINA5's positions and add labels
for _, row in serpina5_rows.iterrows():
    plt.axvline(row['logFC'], color='red', linestyle='--')
    plt.annotate(row['Comparison'], (row['logFC'], 1.05), textcoords="offset points", xytext=(-10,-10), ha='center', fontsize=8, rotation=90)

# Highlight APOE's positions and add labels
for _, row in apoe_rows.iterrows():
    plt.axvline(row['logFC'], color='blue', linestyle='--')
    plt.annotate(row['Comparison'], (row['logFC'], 1.05), textcoords="offset points", xytext=(-10,-10), ha='center', fontsize=8, rotation=90)

# Create a custom legend
from matplotlib.lines import Line2D
custom_lines = [Line2D([0], [0], color='red', lw=2),
                Line2D([0], [0], color='blue', lw=2)]
plt.legend(custom_lines, ['SERPINA5', 'APOE'])

plt.xlim(-0.4, 0.4)
plt.ylim(0, 1.15)  # Increase y-axis limit to make room for labels
plt.show()
